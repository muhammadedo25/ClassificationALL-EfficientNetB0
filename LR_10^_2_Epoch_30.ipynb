# %%
# import system libs
import glob
import os
import time
import shutil
import pathlib
import itertools

# import data handling tools
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import resample
from sklearn.model_selection import KFold

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.activations import relu
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
def undersample_dataframe(df, target_column):
    # Menghitung jumlah sampel untuk setiap kelas
    label_counts = df[target_column].value_counts()

    # Menentukan jumlah sampel terkecil pada kelas
    min_label_count = label_counts.min()

    # Inisialisasi dataframe kosong untuk menyimpan sampel undersampled
    undersampled_df = pd.DataFrame()

    # Melakukan undersampling pada setiap kelas
    for label in label_counts.index:
        # Memilih sampel acak dengan jumlah yang sesuai dari setiap kelas
        undersampled_class_df = resample(
            df[df[target_column] == label],
            replace=False,  # Tidak mengganti sampel yang dipilih
            n_samples=min_label_count,  # Jumlah sampel yang sesuai
            random_state=42  # Seed untuk reproduksi
        )

        # Menyimpan sampel undersampled
        undersampled_df = pd.concat([undersampled_df, undersampled_class_df])

    return undersampled_df

# %%
# Function that create dataframe for train, and test data
def create_df(df_fix):
    # train dataframe
    df = df_fix
    strat = df['labels']
    train_df, test_df = train_test_split(df, train_size=0.8, shuffle=True, random_state=42, stratify=strat)

    return train_df, test_df

# %%
def create_model_data_test (test_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR atau Grayscale
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    ts_length = len(test_df)
    test_batch_size = 32

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    ts_gen = ImageDataGenerator(preprocessing_function= scalar)

    test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= False, batch_size= test_batch_size)

    return test_gen

# %%
def create_model_data_train (train_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    tr_gen = ImageDataGenerator(preprocessing_function= scalar, horizontal_flip= True)

    train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    return train_gen

# %%
def create_model_data_valid (valid_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR atau Grayscale
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    ts_gen = ImageDataGenerator(preprocessing_function= scalar)

    valid_gen = ts_gen.flow_from_dataframe( valid_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    return valid_gen

# %%
def show_images(gen):

    # mengembalikan kelas, gambar yang akan ditampilkan
    g_dict = gen.class_indices        # defines dictionary {'class': index}
    classes = list(g_dict.keys())     # mendefinisikan list dari dictionary keys (classes), classes names : string
    images, labels = next(gen)        # dapatkan ukuran batch size samples dari generator

    # menghitung banyaknya sample yang ditampilkan
    length = len(labels)        # panjang dari batch size
    sample = min(length, 25)    # cek jika sample kurang dari 25 gambar

    plt.figure(figsize= (20, 20))

    for i in range(sample):
        plt.subplot(5, 5, i + 1)
        image = images[i] / 255       # menskalakan data dalam rentang (0 - 255)
        plt.imshow(image)
        index = np.argmax(labels[i])  # dapatkan index gambar
        class_name = classes[index]   # dapatkan class dari gambar
        plt.title(class_name, color= 'blue', fontsize= 12)
        plt.axis('off')
    plt.show()

# %%
GCS_PATH = '/content/drive/MyDrive/Leukemia/'

# Membaca Data Train

train_dataset_0_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_0/all/*.bmp')
train_dataset_0_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_0/hem/*.bmp')
train_dataset_1_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_1/all/*.bmp')
train_dataset_1_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_1/hem/*.bmp')
train_dataset_2_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_2/all/*.bmp')
train_dataset_2_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_2/hem/*.bmp')

# Merging data:-
A=[]
H=[]

A.extend(train_dataset_0_all)
A.extend(train_dataset_1_all)
A.extend(train_dataset_2_all)

H.extend(train_dataset_0_hem)
H.extend(train_dataset_1_hem)
H.extend(train_dataset_2_hem)

print('Data Train')
print(len(A))
print(len(H))

# Membuat labels :-
Label_A = [1]*len(A)
Label_H = [0]*len(H)

# Convert ke pandas dataframe untuk memudahkan akses:-
A.extend(H)
Label_A.extend(Label_H)
df = pd.DataFrame({'filepaths':A, 'labels':Label_A})
df = df.sample(frac=1).reset_index(drop=True)

# Include Validation data
test_data=pd.read_csv(GCS_PATH + 'C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data_labels.csv')

at = test_data[test_data['labels'] == 1]
ht = test_data[test_data['labels'] == 0]

test_PATH = GCS_PATH + 'C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/'
ATL = [test_PATH +  i for i in list(at.new_names)]
HTL = [test_PATH +  i for i in list(ht.new_names)]

TA=[]
TH=[]

TA.extend(ATL)
TH.extend(HTL)

print('\nData Test')
print(len(TA))
print(len(TH))

# Membuat Tabel
Label_TA = [1]*len(TA)
Label_TH = [0]*len(TH)

# Convert ke Pandas DataFrame
TA.extend(TH)
Label_TA.extend(Label_TH)
tdf = pd.DataFrame({'filepaths':TA, 'labels':Label_TA})
tdf = tdf.sample(frac=1).reset_index(drop=True)
# Out:
# Data Train
# 7272
# 3389
#
# Data Test
# 1219
# 648

# %%
df_combined = pd.concat([df, tdf], ignore_index=True)
df_combined['labels'] = df_combined['labels'].replace({1: 'all', 0: 'hem'})
df_combined
# Out:
#                                                filepaths labels
# 0      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 1      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 2      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 3      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 4      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# ...                                                  ...    ...
# 12523  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 12524  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 12525  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 12526  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 12527  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
#
# [12528 rows x 2 columns]

# %%
df_fix = undersample_dataframe(df_combined, 'labels')
df_fix = df_fix.reset_index(drop=True)
df_fix
# Out:
#                                               filepaths labels
# 0     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 1     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 2     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 3     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 4     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# ...                                                 ...    ...
# 8069  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8070  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8071  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8072  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8073  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
#
# [8074 rows x 2 columns]

# %%
print("Total number of images in the dataset: ", len(df_fix))

label_count = df_fix['labels'].value_counts()
print(label_count)
# Out:
# Total number of images in the dataset:  8074
# all    4037
# hem    4037
# Name: labels, dtype: int64

# %%
# Get splitted data
train_df, test_df = create_df(df_fix)

# Get Generators
batch_size = 32
test_gen = create_model_data_test(test_df, batch_size)
# Out:
# Found 1615 validated image filenames belonging to 2 classes.

# %%
show_images(test_gen)

# %%
def plot_training(hist):
    '''
    Function ini mengambil model pelatihan dan riwayat plot akurasi dan loss dengan epoch terbaik di keduanya.
    '''

    # Define variables yang dibutuhkan
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training dan Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training dan Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
def plot_confusion_matrix(cm, classes, title= 'Confusion Matrix', cmap= plt.cm.Blues):
    '''
    Function ini digunakan untuk memplot confusion matrix menggunakan sklearn package.
    '''

    plt.figure(figsize= (10, 10))
    plt.imshow(cm, interpolation= 'nearest', cmap= cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation= 45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')

# %%
def efficientNet_B0():
    # Create Model Structure
    img_size = (224, 224)
    channels = 3
    img_shape = (img_size[0], img_size[1], channels)

    base_model = tf.keras.applications.efficientnet.EfficientNetB0(include_top= False, weights= 'imagenet', input_shape= img_shape, pooling= 'max')

    model = Sequential([
        base_model,
        BatchNormalization(),
        Dense(256, activation=relu),
        Dropout(0.2),
        Dense(2, activation='sigmoid')
    ])
    model.compile(Adamax(learning_rate= 0.01), loss= 'binary_crossentropy', metrics= ['accuracy'])

    return model

# %%
history_list, model_list = [], []
train_data, val_data  = [], []
duration_list = []
kfold=5
epochs=30
fold = 1

kf = KFold(n_splits=kfold, shuffle=True, random_state=42)
fold_indices = kf.split(train_df)

for fold, (train_index, val_index) in enumerate(fold_indices):
    print(f'\nFOLD: {fold+1}')

    # Inisialisasi DataFrame baru untuk menyimpan data pelatihan dan validation
    train_subset_df = pd.DataFrame()
    valid_subset_df = pd.DataFrame()

    fold_train_df = train_df.iloc[train_index] # Bagi data menjadi set pelatihan dan validasi
    fold_valid_df = train_df.iloc[val_index]

    # Tambahkan data pelatihan dan validation pada lipatan ini ke DataFrame baru
    train_subset_df = pd.concat([train_subset_df, fold_train_df], ignore_index=True)
    valid_subset_df = pd.concat([valid_subset_df, fold_valid_df], ignore_index=True)

    train_gen = create_model_data_train(train_subset_df, batch_size) # generate data train dan valid
    valid_gen = create_model_data_valid(valid_subset_df, batch_size)

    K.clear_session()
    print('\nMODEL SUMMARY:')
    model = efficientNet_B0()
    model.summary()

    print('\nFITTING MODEL:')
    start_time = time.time() # mencatat waktu mulai
    history = model.fit(x= train_gen, epochs= epochs, verbose= 1,
                    validation_data= valid_gen, validation_steps= None, shuffle= False)


    stop_time = time.time()
    tr_duration = stop_time - start_time
    hours = tr_duration // 3600
    minutes = (tr_duration - (hours * 3600)) // 60
    seconds = tr_duration - ((hours * 3600) + (minutes * 60))
    sum_duration = {
        'hours' : hours,
        'minutes' : minutes,
        'seconds' : seconds
    }

    duration_list.append(sum_duration)

    history_list.append(history)
    model_list.append(model)

    train_data.append(train_gen)
    val_data.append(valid_gen)
# Out:
# FOLD: 1
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/30
# 162/162 [==============================] - 52s 145ms/step - loss: 1.0548 - accuracy: 0.6811 - val_loss: 438.6260 - val_accuracy: 0.5108
# Epoch 2/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.5970 - accuracy: 0.7314 - val_loss: 0.5889 - val_accuracy: 0.6796
# Epoch 3/30
# 162/162 [==============================] - 22s 133ms/step - loss: 0.5432 - accuracy: 0.7478 - val_loss: 1.0281 - val_accuracy: 0.4892
# Epoch 4/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.5625 - accuracy: 0.7623 - val_loss: 0.8860 - val_accuracy: 0.4892
# Epoch 5/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.5035 - accuracy: 0.7712 - val_loss: 0.5518 - val_accuracy: 0.7067
# Epoch 6/30
# 162/162 [==============================] - 22s 133ms/step - loss: 0.4508 - accuracy: 0.7995 - val_loss: 0.5915 - val_accuracy: 0.6819
# Epoch 7/30
# 162/162 [==============================] - 22s 133ms/step - loss: 0.3996 - accuracy: 0.8231 - val_loss: 1.5438 - val_accuracy: 0.5039
# Epoch 8/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3753 - accuracy: 0.8398 - val_loss: 0.8535 - val_accuracy: 0.5898
# Epoch 9/30
# 162/162 [==============================] - 22s 133ms/step - loss: 0.3604 - accuracy: 0.8446 - val_loss: 0.3273 - val_accuracy: 0.8591
# Epoch 10/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3332 - accuracy: 0.8589 - val_loss: 0.4521 - val_accuracy: 0.7910
# Epoch 11/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3204 - accuracy: 0.8674 - val_loss: 0.5562 - val_accuracy: 0.7260
# Epoch 12/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3009 - accuracy: 0.8787 - val_loss: 0.4218 - val_accuracy: 0.8104
# Epoch 13/30
# 162/162 [==============================] - 22s 133ms/step - loss: 0.2805 - accuracy: 0.8895 - val_loss: 0.9348 - val_accuracy: 0.8050
# Epoch 14/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2776 - accuracy: 0.8852 - val_loss: 0.4562 - val_accuracy: 0.7724
# Epoch 15/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2861 - accuracy: 0.8837 - val_loss: 0.6023 - val_accuracy: 0.6354
# Epoch 16/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2563 - accuracy: 0.8951 - val_loss: 0.8454 - val_accuracy: 0.6409
# Epoch 17/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2428 - accuracy: 0.9011 - val_loss: 0.5990 - val_accuracy: 0.7701
# Epoch 18/30
# 162/162 [==============================] - 22s 133ms/step - loss: 0.2293 - accuracy: 0.9104 - val_loss: 0.4445 - val_accuracy: 0.7988
# Epoch 19/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2126 - accuracy: 0.9197 - val_loss: 1.1480 - val_accuracy: 0.5944
# Epoch 20/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1876 - accuracy: 0.9268 - val_loss: 0.9987 - val_accuracy: 0.6935
# Epoch 21/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2047 - accuracy: 0.9135 - val_loss: 1.5104 - val_accuracy: 0.5441
# Epoch 22/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2221 - accuracy: 0.9108 - val_loss: 2.2687 - val_accuracy: 0.6827
# Epoch 23/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1854 - accuracy: 0.9268 - val_loss: 0.3437 - val_accuracy: 0.8986
# Epoch 24/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1607 - accuracy: 0.9377 - val_loss: 4.9147 - val_accuracy: 0.5116
# Epoch 25/30
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1668 - accuracy: 0.9373 - val_loss: 0.8362 - val_accuracy: 0.6401
# Epoch 26/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1455 - accuracy: 0.9445 - val_loss: 0.5698 - val_accuracy: 0.7701
# Epoch 27/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1294 - accuracy: 0.9534 - val_loss: 2.3196 - val_accuracy: 0.5379
# Epoch 28/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1462 - accuracy: 0.9427 - val_loss: 0.3104 - val_accuracy: 0.8692
# Epoch 29/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1149 - accuracy: 0.9584 - val_loss: 0.4554 - val_accuracy: 0.8452
# Epoch 30/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1290 - accuracy: 0.9526 - val_loss: 0.5208 - val_accuracy: 0.8545
#
# FOLD: 2
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/30
# 162/162 [==============================] - 48s 138ms/step - loss: 1.2042 - accuracy: 0.6874 - val_loss: 0.6343 - val_accuracy: 0.6602
# Epoch 2/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.6676 - accuracy: 0.7461 - val_loss: 0.5153 - val_accuracy: 0.7515
# Epoch 3/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.4616 - accuracy: 0.7889 - val_loss: 0.6044 - val_accuracy: 0.7531
# Epoch 4/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.4356 - accuracy: 0.8028 - val_loss: 0.4209 - val_accuracy: 0.8096
# Epoch 5/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3964 - accuracy: 0.8295 - val_loss: 0.4191 - val_accuracy: 0.8073
# Epoch 6/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3366 - accuracy: 0.8550 - val_loss: 0.6615 - val_accuracy: 0.5913
# Epoch 7/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3130 - accuracy: 0.8680 - val_loss: 0.5867 - val_accuracy: 0.6045
# Epoch 8/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2977 - accuracy: 0.8734 - val_loss: 1.1369 - val_accuracy: 0.5658
# Epoch 9/30
# 162/162 [==============================] - 22s 132ms/step - loss: 0.2717 - accuracy: 0.8864 - val_loss: 0.3500 - val_accuracy: 0.8800
# Epoch 10/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2536 - accuracy: 0.8984 - val_loss: 2.1949 - val_accuracy: 0.5000
# Epoch 11/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2560 - accuracy: 0.8955 - val_loss: 0.5084 - val_accuracy: 0.7724
# Epoch 12/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2504 - accuracy: 0.8974 - val_loss: 0.5546 - val_accuracy: 0.8313
# Epoch 13/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2480 - accuracy: 0.8963 - val_loss: 0.6045 - val_accuracy: 0.6711
# Epoch 14/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2468 - accuracy: 0.9017 - val_loss: 0.2636 - val_accuracy: 0.8963
# Epoch 15/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2358 - accuracy: 0.9087 - val_loss: 1.5363 - val_accuracy: 0.5364
# Epoch 16/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2269 - accuracy: 0.9081 - val_loss: 0.6205 - val_accuracy: 0.6896
# Epoch 17/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2433 - accuracy: 0.9056 - val_loss: 0.4342 - val_accuracy: 0.8204
# Epoch 18/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2021 - accuracy: 0.9234 - val_loss: 0.4515 - val_accuracy: 0.8173
# Epoch 19/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2063 - accuracy: 0.9137 - val_loss: 0.4064 - val_accuracy: 0.8344
# Epoch 20/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3611 - accuracy: 0.8835 - val_loss: 1.0398 - val_accuracy: 0.7554
# Epoch 21/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2041 - accuracy: 0.9241 - val_loss: 0.2747 - val_accuracy: 0.8839
# Epoch 22/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1754 - accuracy: 0.9344 - val_loss: 3.0317 - val_accuracy: 0.5000
# Epoch 23/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1622 - accuracy: 0.9385 - val_loss: 0.9950 - val_accuracy: 0.7345
# Epoch 24/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1547 - accuracy: 0.9390 - val_loss: 0.2835 - val_accuracy: 0.8971
# Epoch 25/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1582 - accuracy: 0.9417 - val_loss: 5.8314 - val_accuracy: 0.5093
# Epoch 26/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1339 - accuracy: 0.9470 - val_loss: 1.2124 - val_accuracy: 0.6207
# Epoch 27/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1477 - accuracy: 0.9443 - val_loss: 0.6148 - val_accuracy: 0.6889
# Epoch 28/30
# 162/162 [==============================] - 22s 132ms/step - loss: 0.1483 - accuracy: 0.9433 - val_loss: 0.9736 - val_accuracy: 0.7337
# Epoch 29/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1464 - accuracy: 0.9406 - val_loss: 0.3996 - val_accuracy: 0.8282
# Epoch 30/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1431 - accuracy: 0.9458 - val_loss: 0.8720 - val_accuracy: 0.8700
#
# FOLD: 3
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/30
# 162/162 [==============================] - 50s 139ms/step - loss: 1.0584 - accuracy: 0.6764 - val_loss: 0.6846 - val_accuracy: 0.7059
# Epoch 2/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.5690 - accuracy: 0.7515 - val_loss: 0.5667 - val_accuracy: 0.7469
# Epoch 3/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.4667 - accuracy: 0.7859 - val_loss: 0.7678 - val_accuracy: 0.4946
# Epoch 4/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.4513 - accuracy: 0.7861 - val_loss: 0.5612 - val_accuracy: 0.6997
# Epoch 5/30
# 162/162 [==============================] - 22s 133ms/step - loss: 0.4292 - accuracy: 0.8041 - val_loss: 0.5024 - val_accuracy: 0.7810
# Epoch 6/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.4260 - accuracy: 0.8065 - val_loss: 1.4645 - val_accuracy: 0.5294
# Epoch 7/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.4101 - accuracy: 0.8154 - val_loss: 0.5755 - val_accuracy: 0.6904
# Epoch 8/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3894 - accuracy: 0.8225 - val_loss: 0.6519 - val_accuracy: 0.7074
# Epoch 9/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3977 - accuracy: 0.8268 - val_loss: 0.9584 - val_accuracy: 0.4946
# Epoch 10/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3754 - accuracy: 0.8299 - val_loss: 0.4074 - val_accuracy: 0.7995
# Epoch 11/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.3537 - accuracy: 0.8436 - val_loss: 0.5341 - val_accuracy: 0.7245
# Epoch 12/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3215 - accuracy: 0.8585 - val_loss: 0.5758 - val_accuracy: 0.7430
# Epoch 13/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3154 - accuracy: 0.8634 - val_loss: 0.3231 - val_accuracy: 0.8483
# Epoch 14/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3200 - accuracy: 0.8618 - val_loss: 0.3775 - val_accuracy: 0.8212
# Epoch 15/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3227 - accuracy: 0.8603 - val_loss: 0.6587 - val_accuracy: 0.6718
# Epoch 16/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2823 - accuracy: 0.8785 - val_loss: 0.3136 - val_accuracy: 0.8816
# Epoch 17/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2770 - accuracy: 0.8831 - val_loss: 0.3196 - val_accuracy: 0.8622
# Epoch 18/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2324 - accuracy: 0.9027 - val_loss: 0.7736 - val_accuracy: 0.8189
# Epoch 19/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2293 - accuracy: 0.9090 - val_loss: 0.5054 - val_accuracy: 0.7732
# Epoch 20/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2246 - accuracy: 0.9100 - val_loss: 0.4549 - val_accuracy: 0.9009
# Epoch 21/30
# 162/162 [==============================] - 22s 132ms/step - loss: 0.2184 - accuracy: 0.9123 - val_loss: 0.5405 - val_accuracy: 0.8282
# Epoch 22/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2002 - accuracy: 0.9191 - val_loss: 0.7103 - val_accuracy: 0.7136
# Epoch 23/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2062 - accuracy: 0.9170 - val_loss: 0.3167 - val_accuracy: 0.8707
# Epoch 24/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1874 - accuracy: 0.9226 - val_loss: 0.4630 - val_accuracy: 0.8576
# Epoch 25/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1813 - accuracy: 0.9239 - val_loss: 1.7196 - val_accuracy: 0.6579
# Epoch 26/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1799 - accuracy: 0.9338 - val_loss: 0.5597 - val_accuracy: 0.7902
# Epoch 27/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1992 - accuracy: 0.9299 - val_loss: 1.3530 - val_accuracy: 0.5426
# Epoch 28/30
# 162/162 [==============================] - 22s 132ms/step - loss: 0.1584 - accuracy: 0.9369 - val_loss: 0.3919 - val_accuracy: 0.8359
# Epoch 29/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1401 - accuracy: 0.9445 - val_loss: 0.3172 - val_accuracy: 0.8831
# Epoch 30/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1537 - accuracy: 0.9412 - val_loss: 0.8373 - val_accuracy: 0.6997
#
# FOLD: 4
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/30
# 162/162 [==============================] - 48s 139ms/step - loss: 1.0291 - accuracy: 0.7041 - val_loss: 0.6635 - val_accuracy: 0.7415
# Epoch 2/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.4741 - accuracy: 0.7765 - val_loss: 0.5183 - val_accuracy: 0.7345
# Epoch 3/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.4190 - accuracy: 0.8065 - val_loss: 0.9172 - val_accuracy: 0.5163
# Epoch 4/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3818 - accuracy: 0.8297 - val_loss: 0.6086 - val_accuracy: 0.7198
# Epoch 5/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3438 - accuracy: 0.8518 - val_loss: 1.5563 - val_accuracy: 0.6122
# Epoch 6/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3147 - accuracy: 0.8725 - val_loss: 1.0999 - val_accuracy: 0.6602
# Epoch 7/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2770 - accuracy: 0.8877 - val_loss: 0.3531 - val_accuracy: 0.8328
# Epoch 8/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2610 - accuracy: 0.8914 - val_loss: 0.3634 - val_accuracy: 0.8669
# Epoch 9/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2516 - accuracy: 0.9001 - val_loss: 0.9798 - val_accuracy: 0.7632
# Epoch 10/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.2290 - accuracy: 0.9073 - val_loss: 0.3256 - val_accuracy: 0.8467
# Epoch 11/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2329 - accuracy: 0.9057 - val_loss: 0.3404 - val_accuracy: 0.8591
# Epoch 12/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2177 - accuracy: 0.9112 - val_loss: 0.7812 - val_accuracy: 0.7376
# Epoch 13/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2007 - accuracy: 0.9191 - val_loss: 2.4171 - val_accuracy: 0.6022
# Epoch 14/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2103 - accuracy: 0.9162 - val_loss: 1.1232 - val_accuracy: 0.6362
# Epoch 15/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2064 - accuracy: 0.9114 - val_loss: 3.3476 - val_accuracy: 0.6494
# Epoch 16/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2070 - accuracy: 0.9183 - val_loss: 0.3737 - val_accuracy: 0.8375
# Epoch 17/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1696 - accuracy: 0.9330 - val_loss: 0.7878 - val_accuracy: 0.8135
# Epoch 18/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1806 - accuracy: 0.9294 - val_loss: 0.2340 - val_accuracy: 0.9040
# Epoch 19/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1650 - accuracy: 0.9344 - val_loss: 0.4341 - val_accuracy: 0.8467
# Epoch 20/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1561 - accuracy: 0.9398 - val_loss: 0.5260 - val_accuracy: 0.8228
# Epoch 21/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1525 - accuracy: 0.9448 - val_loss: 2.1518 - val_accuracy: 0.5937
# Epoch 22/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1533 - accuracy: 0.9448 - val_loss: 1.0860 - val_accuracy: 0.5341
# Epoch 23/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0957 - accuracy: 0.9652 - val_loss: 0.5502 - val_accuracy: 0.8800
# Epoch 24/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.0731 - accuracy: 0.9745 - val_loss: 0.3604 - val_accuracy: 0.8955
# Epoch 25/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0514 - accuracy: 0.9803 - val_loss: 0.5546 - val_accuracy: 0.8235
# Epoch 26/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0618 - accuracy: 0.9791 - val_loss: 0.7438 - val_accuracy: 0.8150
# Epoch 27/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0523 - accuracy: 0.9781 - val_loss: 0.4347 - val_accuracy: 0.8924
# Epoch 28/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0722 - accuracy: 0.9766 - val_loss: 0.3244 - val_accuracy: 0.8901
# Epoch 29/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.0490 - accuracy: 0.9837 - val_loss: 0.3942 - val_accuracy: 0.8940
# Epoch 30/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0518 - accuracy: 0.9824 - val_loss: 0.4064 - val_accuracy: 0.8824
#
# FOLD: 5
# Found 5168 validated image filenames belonging to 2 classes.
# Found 1291 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/30
# 162/162 [==============================] - 50s 138ms/step - loss: 1.0592 - accuracy: 0.6972 - val_loss: 1.2107 - val_accuracy: 0.5143
# Epoch 2/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.4852 - accuracy: 0.7746 - val_loss: 0.5544 - val_accuracy: 0.7235
# Epoch 3/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.4363 - accuracy: 0.7943 - val_loss: 0.6502 - val_accuracy: 0.6174
# Epoch 4/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.4009 - accuracy: 0.8133 - val_loss: 0.5803 - val_accuracy: 0.7188
# Epoch 5/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3869 - accuracy: 0.8239 - val_loss: 2.1833 - val_accuracy: 0.4888
# Epoch 6/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3517 - accuracy: 0.8417 - val_loss: 0.4449 - val_accuracy: 0.7916
# Epoch 7/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.3492 - accuracy: 0.8433 - val_loss: 2.1732 - val_accuracy: 0.5128
# Epoch 8/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3239 - accuracy: 0.8560 - val_loss: 0.5134 - val_accuracy: 0.7723
# Epoch 9/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3024 - accuracy: 0.8669 - val_loss: 0.6014 - val_accuracy: 0.6793
# Epoch 10/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2898 - accuracy: 0.8824 - val_loss: 0.5861 - val_accuracy: 0.7932
# Epoch 11/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2866 - accuracy: 0.8854 - val_loss: 1.2729 - val_accuracy: 0.5259
# Epoch 12/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2671 - accuracy: 0.8847 - val_loss: 0.8476 - val_accuracy: 0.6971
# Epoch 13/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2500 - accuracy: 0.8934 - val_loss: 1.3272 - val_accuracy: 0.5608
# Epoch 14/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2494 - accuracy: 0.8973 - val_loss: 1.2258 - val_accuracy: 0.5895
# Epoch 15/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2212 - accuracy: 0.9040 - val_loss: 0.6812 - val_accuracy: 0.6739
# Epoch 16/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2024 - accuracy: 0.9151 - val_loss: 0.7547 - val_accuracy: 0.7242
# Epoch 17/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1969 - accuracy: 0.9253 - val_loss: 2.3781 - val_accuracy: 0.5476
# Epoch 18/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1889 - accuracy: 0.9290 - val_loss: 0.4283 - val_accuracy: 0.8397
# Epoch 19/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1897 - accuracy: 0.9269 - val_loss: 0.7869 - val_accuracy: 0.7157
# Epoch 20/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1561 - accuracy: 0.9373 - val_loss: 3.0365 - val_accuracy: 0.7637
# Epoch 21/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1616 - accuracy: 0.9404 - val_loss: 0.8814 - val_accuracy: 0.6801
# Epoch 22/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.1394 - accuracy: 0.9476 - val_loss: 2.5661 - val_accuracy: 0.6088
# Epoch 23/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1321 - accuracy: 0.9510 - val_loss: 0.3324 - val_accuracy: 0.8854
# Epoch 24/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1640 - accuracy: 0.9408 - val_loss: 1.2500 - val_accuracy: 0.6762
# Epoch 25/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1203 - accuracy: 0.9547 - val_loss: 0.7016 - val_accuracy: 0.7940
# Epoch 26/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1057 - accuracy: 0.9607 - val_loss: 0.5410 - val_accuracy: 0.7854
# Epoch 27/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0890 - accuracy: 0.9673 - val_loss: 0.3376 - val_accuracy: 0.8923
# Epoch 28/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.0820 - accuracy: 0.9694 - val_loss: 1.2530 - val_accuracy: 0.7537
# Epoch 29/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0928 - accuracy: 0.9663 - val_loss: 0.7050 - val_accuracy: 0.7459
# Epoch 30/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0901 - accuracy: 0.9683 - val_loss: 0.6115 - val_accuracy: 0.7785

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_training(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3
# FOLD: 4
# FOLD: 5

# %%
test_batch_size = 32
validation_accuracies = []

for fold, model in enumerate(model_list):
    print(f'\nFOLD: {fold+1}')
    train_score = model.evaluate(train_data[fold], batch_size=test_batch_size, verbose= 1)
    valid_score = model.evaluate(val_data[fold], batch_size=test_batch_size, verbose= 1)

    print('-' * 20)
    print("Train Loss: ", train_score[0])
    print("Train Accuracy: ", train_score[1])
    print('-' * 20)
    print("Validation Loss: ", valid_score[0])
    print("Validation Accuracy: ", valid_score[1])
    print('-' * 20)

    validation_accuracies.append(valid_score[1])
    hours = duration_list[fold]['hours']
    minutes = duration_list[fold]['minutes']
    seconds = duration_list[fold]['seconds']

    msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
    print(msg)

best_fold = np.argmax(validation_accuracies)
best_model = model_list[best_fold]
print ("Best Fold berada pada : ",best_fold)
print (best_model)
# Out:
# FOLD: 1
# 162/162 [==============================] - 16s 96ms/step - loss: 0.2065 - accuracy: 0.9232
# 41/41 [==============================] - 4s 88ms/step - loss: 0.5208 - accuracy: 0.8545
# --------------------
# Train Loss:  0.2064858376979828
# Train Accuracy:  0.9231662750244141
# --------------------
# Validation Loss:  0.5207821130752563
# Validation Accuracy:  0.8544891476631165
# --------------------
# training elapsed time was 0.0 hours, 11.0 minutes, 12.03 seconds)
#
# FOLD: 2
# 162/162 [==============================] - 15s 94ms/step - loss: 0.4091 - accuracy: 0.9197
# 41/41 [==============================] - 4s 86ms/step - loss: 0.8720 - accuracy: 0.8700
# --------------------
# Train Loss:  0.40913325548171997
# Train Accuracy:  0.9196826219558716
# --------------------
# Validation Loss:  0.8719791173934937
# Validation Accuracy:  0.8699690699577332
# --------------------
# training elapsed time was 0.0 hours, 11.0 minutes, 4.65 seconds)
#
# FOLD: 3
# 162/162 [==============================] - 15s 92ms/step - loss: 0.6467 - accuracy: 0.7343
# 41/41 [==============================] - 4s 87ms/step - loss: 0.8373 - accuracy: 0.6997
# --------------------
# Train Loss:  0.6466876864433289
# Train Accuracy:  0.734275221824646
# --------------------
# Validation Loss:  0.8372893333435059
# Validation Accuracy:  0.6996904015541077
# --------------------
# training elapsed time was 0.0 hours, 11.0 minutes, 8.14 seconds)
#
# FOLD: 4
# 162/162 [==============================] - 15s 91ms/step - loss: 0.1033 - accuracy: 0.9597
# 41/41 [==============================] - 4s 85ms/step - loss: 0.4064 - accuracy: 0.8824
# --------------------
# Train Loss:  0.10331021994352341
# Train Accuracy:  0.9597445130348206
# --------------------
# Validation Loss:  0.4064265489578247
# Validation Accuracy:  0.8823529481887817
# --------------------
# training elapsed time was 0.0 hours, 11.0 minutes, 0.08 seconds)
#
# FOLD: 5
# 162/162 [==============================] - 15s 90ms/step - loss: 0.3803 - accuracy: 0.8382
# 41/41 [==============================] - 3s 84ms/step - loss: 0.6115 - accuracy: 0.7785
# --------------------
# Train Loss:  0.38026824593544006
# Train Accuracy:  0.8382353186607361
# --------------------
# Validation Loss:  0.6114581823348999
# Validation Accuracy:  0.7784662842750549
# --------------------
# training elapsed time was 0.0 hours, 11.0 minutes, 0.13 seconds)
# Best Fold berada pada :  3
# <keras.src.engine.sequential.Sequential object at 0x79c918d00130>

# %%
preds = best_model.predict_generator(test_gen, verbose=1)
y_pred = np.argmax(preds, axis=1)
print(y_pred)
# Out:
# 51/51 [==============================] - 4s 87ms/step
# [1 0 1 ... 1 1 1]

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

cm = confusion_matrix(test_gen.classes, y_pred)
plot_confusion_matrix(cm= cm, classes= classes, title = 'Confusion Matrix')

    # Classification report
print(classification_report(test_gen.classes, y_pred, target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#          all       0.95      0.60      0.74       808
#          hem       0.71      0.97      0.82       807
#
#     accuracy                           0.78      1615
#    macro avg       0.83      0.78      0.78      1615
# weighted avg       0.83      0.78      0.78      1615

# %%
from sklearn import metrics


y_prob = []

for data in preds:
    y_prob.append(data[1])

fpr, tpr, thresholds = metrics.roc_curve(test_gen.classes, y_prob)
auc = metrics.auc(fpr, tpr)

plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], 'k--')  # Garis diagonal untuk klasifikasi acak
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()
