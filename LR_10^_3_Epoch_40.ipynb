# %%
# import system libs
import glob
import os
import time
import shutil
import pathlib
import itertools

# import data handling tools
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import resample
from sklearn.model_selection import KFold

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.activations import relu
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
def undersample_dataframe(df, target_column):
    # Menghitung jumlah sampel untuk setiap kelas
    label_counts = df[target_column].value_counts()

    # Menentukan jumlah sampel terkecil pada kelas
    min_label_count = label_counts.min()

    # Inisialisasi dataframe kosong untuk menyimpan sampel undersampled
    undersampled_df = pd.DataFrame()

    # Melakukan undersampling pada setiap kelas
    for label in label_counts.index:
        # Memilih sampel acak dengan jumlah yang sesuai dari setiap kelas
        undersampled_class_df = resample(
            df[df[target_column] == label],
            replace=False,  # Tidak mengganti sampel yang dipilih
            n_samples=min_label_count,  # Jumlah sampel yang sesuai
            random_state=42  # Seed untuk reproduksi
        )

        # Menyimpan sampel undersampled
        undersampled_df = pd.concat([undersampled_df, undersampled_class_df])

    return undersampled_df

# %%
# Function that create dataframe for train, and test data
def create_df(df_fix):
    # train dataframe
    df = df_fix
    strat = df['labels']
    train_df, test_df = train_test_split(df, train_size=0.8, shuffle=True, random_state=42, stratify=strat)

    return train_df, test_df

# %%
def create_model_data_test (test_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR atau Grayscale
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    ts_length = len(test_df)
    test_batch_size = 32

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    ts_gen = ImageDataGenerator(preprocessing_function= scalar)

    test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= False, batch_size= test_batch_size)

    return test_gen

# %%
def create_model_data_train (train_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    tr_gen = ImageDataGenerator(preprocessing_function= scalar, horizontal_flip= True)

    train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    return train_gen

# %%
def create_model_data_valid (valid_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR atau Grayscale
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    ts_gen = ImageDataGenerator(preprocessing_function= scalar)

    valid_gen = ts_gen.flow_from_dataframe( valid_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    return valid_gen

# %%
def show_images(gen):

    # mengembalikan kelas, gambar yang akan ditampilkan
    g_dict = gen.class_indices        # defines dictionary {'class': index}
    classes = list(g_dict.keys())     # mendefinisikan list dari dictionary keys (classes), classes names : string
    images, labels = next(gen)        # dapatkan ukuran batch size samples dari generator

    # menghitung banyaknya sample yang ditampilkan
    length = len(labels)        # panjang dari batch size
    sample = min(length, 25)    # cek jika sample kurang dari 25 gambar

    plt.figure(figsize= (20, 20))

    for i in range(sample):
        plt.subplot(5, 5, i + 1)
        image = images[i] / 255       # menskalakan data dalam rentang (0 - 255)
        plt.imshow(image)
        index = np.argmax(labels[i])  # dapatkan index gambar
        class_name = classes[index]   # dapatkan class dari gambar
        plt.title(class_name, color= 'blue', fontsize= 12)
        plt.axis('off')
    plt.show()

# %%
GCS_PATH = '/content/drive/MyDrive/Leukemia/'

# Membaca Data Train

train_dataset_0_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_0/all/*.bmp')
train_dataset_0_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_0/hem/*.bmp')
train_dataset_1_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_1/all/*.bmp')
train_dataset_1_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_1/hem/*.bmp')
train_dataset_2_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_2/all/*.bmp')
train_dataset_2_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_2/hem/*.bmp')

# Merging data:-
A=[]
H=[]

A.extend(train_dataset_0_all)
A.extend(train_dataset_1_all)
A.extend(train_dataset_2_all)

H.extend(train_dataset_0_hem)
H.extend(train_dataset_1_hem)
H.extend(train_dataset_2_hem)

print('Data Train')
print(len(A))
print(len(H))

# Membuat labels :-
Label_A = [1]*len(A)
Label_H = [0]*len(H)

# Convert ke pandas dataframe untuk memudahkan akses:-
A.extend(H)
Label_A.extend(Label_H)
df = pd.DataFrame({'filepaths':A, 'labels':Label_A})
df = df.sample(frac=1).reset_index(drop=True)

# Include Validation data
test_data=pd.read_csv(GCS_PATH + 'C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data_labels.csv')

at = test_data[test_data['labels'] == 1]
ht = test_data[test_data['labels'] == 0]

test_PATH = GCS_PATH + 'C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/'
ATL = [test_PATH +  i for i in list(at.new_names)]
HTL = [test_PATH +  i for i in list(ht.new_names)]

TA=[]
TH=[]

TA.extend(ATL)
TH.extend(HTL)

print('\nData Test')
print(len(TA))
print(len(TH))

# Membuat Tabel
Label_TA = [1]*len(TA)
Label_TH = [0]*len(TH)

# Convert ke Pandas DataFrame
TA.extend(TH)
Label_TA.extend(Label_TH)
tdf = pd.DataFrame({'filepaths':TA, 'labels':Label_TA})
tdf = tdf.sample(frac=1).reset_index(drop=True)
# Out:
# Data Train
# 7272
# 3389
#
# Data Test
# 1219
# 648

# %%
df_combined = pd.concat([df, tdf], ignore_index=True)
df_combined['labels'] = df_combined['labels'].replace({1: 'all', 0: 'hem'})
df_combined
# Out:
#                                                filepaths labels
# 0      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 1      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 2      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 3      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 4      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# ...                                                  ...    ...
# 12523  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 12524  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 12525  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 12526  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 12527  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
#
# [12528 rows x 2 columns]

# %%
df_fix = undersample_dataframe(df_combined, 'labels')
df_fix = df_fix.reset_index(drop=True)
df_fix
# Out:
#                                               filepaths labels
# 0     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 1     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 2     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 3     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 4     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# ...                                                 ...    ...
# 8069  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8070  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8071  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8072  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8073  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
#
# [8074 rows x 2 columns]

# %%
print("Total number of images in the dataset: ", len(df_fix))

label_count = df_fix['labels'].value_counts()
print(label_count)
# Out:
# Total number of images in the dataset:  8074
# all    4037
# hem    4037
# Name: labels, dtype: int64

# %%
# Get splitted data
train_df, test_df = create_df(df_fix)

# Get Generators
batch_size = 32
test_gen = create_model_data_test(test_df, batch_size)
# Out:
# Found 1615 validated image filenames belonging to 2 classes.

# %%
show_images(test_gen)

# %%
def plot_training(hist):
    '''
    Function ini mengambil model pelatihan dan riwayat plot akurasi dan loss dengan epoch terbaik di keduanya.
    '''

    # Define variables yang dibutuhkan
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training dan Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training dan Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
def plot_confusion_matrix(cm, classes, title= 'Confusion Matrix', cmap= plt.cm.Blues):
    '''
    Function ini digunakan untuk memplot confusion matrix menggunakan sklearn package.
    '''

    plt.figure(figsize= (10, 10))
    plt.imshow(cm, interpolation= 'nearest', cmap= cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation= 45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')

# %%
def efficientNet_B0():
    # Create Model Structure
    img_size = (224, 224)
    channels = 3
    img_shape = (img_size[0], img_size[1], channels)

    base_model = tf.keras.applications.efficientnet.EfficientNetB0(include_top= False, weights= 'imagenet', input_shape= img_shape, pooling= 'max')

    model = Sequential([
        base_model,
        BatchNormalization(),
        Dense(256, activation=relu),
        Dropout(0.2),
        Dense(2, activation='sigmoid')
    ])
    model.compile(Adamax(learning_rate= 0.001), loss= 'binary_crossentropy', metrics= ['accuracy'])

    return model

# %%
history_list, model_list = [], []
train_data, val_data  = [], []
duration_list = []
kfold=5
epochs=40
fold = 1

kf = KFold(n_splits=kfold, shuffle=True, random_state=42)
fold_indices = kf.split(train_df)

for fold, (train_index, val_index) in enumerate(fold_indices):
    print(f'\nFOLD: {fold+1}')

    # Inisialisasi DataFrame baru untuk menyimpan data pelatihan dan validation
    train_subset_df = pd.DataFrame()
    valid_subset_df = pd.DataFrame()

    fold_train_df = train_df.iloc[train_index] # Bagi data menjadi set pelatihan dan validasi
    fold_valid_df = train_df.iloc[val_index]

    # Tambahkan data pelatihan dan validation pada lipatan ini ke DataFrame baru
    train_subset_df = pd.concat([train_subset_df, fold_train_df], ignore_index=True)
    valid_subset_df = pd.concat([valid_subset_df, fold_valid_df], ignore_index=True)

    train_gen = create_model_data_train(train_subset_df, batch_size) # generate data train dan valid
    valid_gen = create_model_data_valid(valid_subset_df, batch_size)

    K.clear_session()
    print('\nMODEL SUMMARY:')
    model = efficientNet_B0()
    model.summary()

    print('\nFITTING MODEL:')
    start_time = time.time() # mencatat waktu mulai
    history = model.fit(x= train_gen, epochs= epochs, verbose= 1,
                    validation_data= valid_gen, validation_steps= None, shuffle= False)


    stop_time = time.time()
    tr_duration = stop_time - start_time
    hours = tr_duration // 3600
    minutes = (tr_duration - (hours * 3600)) // 60
    seconds = tr_duration - ((hours * 3600) + (minutes * 60))
    sum_duration = {
        'hours' : hours,
        'minutes' : minutes,
        'seconds' : seconds
    }

    duration_list.append(sum_duration)

    history_list.append(history)
    model_list.append(model)

    train_data.append(train_gen)
    val_data.append(valid_gen)
# Out:
# FOLD: 1
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/40
# 162/162 [==============================] - 56s 141ms/step - loss: 0.6533 - accuracy: 0.7341 - val_loss: 1.8278 - val_accuracy: 0.5178
# Epoch 2/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.4260 - accuracy: 0.8109 - val_loss: 0.4903 - val_accuracy: 0.7639
# Epoch 3/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3379 - accuracy: 0.8587 - val_loss: 0.3662 - val_accuracy: 0.8359
# Epoch 4/40
# 162/162 [==============================] - 22s 134ms/step - loss: 0.2770 - accuracy: 0.8827 - val_loss: 0.8800 - val_accuracy: 0.7229
# Epoch 5/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.2388 - accuracy: 0.9056 - val_loss: 0.2778 - val_accuracy: 0.8808
# Epoch 6/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1988 - accuracy: 0.9197 - val_loss: 0.4496 - val_accuracy: 0.8011
# Epoch 7/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1923 - accuracy: 0.9263 - val_loss: 0.2944 - val_accuracy: 0.8839
# Epoch 8/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1514 - accuracy: 0.9386 - val_loss: 0.2850 - val_accuracy: 0.9002
# Epoch 9/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1476 - accuracy: 0.9439 - val_loss: 0.3028 - val_accuracy: 0.8854
# Epoch 10/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1315 - accuracy: 0.9501 - val_loss: 0.3797 - val_accuracy: 0.8669
# Epoch 11/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1131 - accuracy: 0.9547 - val_loss: 0.3348 - val_accuracy: 0.8777
# Epoch 12/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0909 - accuracy: 0.9623 - val_loss: 0.4404 - val_accuracy: 0.8862
# Epoch 13/40
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0951 - accuracy: 0.9657 - val_loss: 0.5234 - val_accuracy: 0.8498
# Epoch 14/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0832 - accuracy: 0.9725 - val_loss: 0.2745 - val_accuracy: 0.9071
# Epoch 15/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0834 - accuracy: 0.9694 - val_loss: 0.2680 - val_accuracy: 0.8932
# Epoch 16/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0682 - accuracy: 0.9710 - val_loss: 0.3514 - val_accuracy: 0.8901
# Epoch 17/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0512 - accuracy: 0.9805 - val_loss: 0.7261 - val_accuracy: 0.8444
# Epoch 18/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0572 - accuracy: 0.9781 - val_loss: 0.4009 - val_accuracy: 0.9017
# Epoch 19/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0472 - accuracy: 0.9816 - val_loss: 0.3723 - val_accuracy: 0.9195
# Epoch 20/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0459 - accuracy: 0.9828 - val_loss: 0.4128 - val_accuracy: 0.9009
# Epoch 21/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0362 - accuracy: 0.9859 - val_loss: 0.4068 - val_accuracy: 0.9102
# Epoch 22/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0486 - accuracy: 0.9845 - val_loss: 0.4371 - val_accuracy: 0.9040
# Epoch 23/40
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0411 - accuracy: 0.9845 - val_loss: 0.3895 - val_accuracy: 0.9172
# Epoch 24/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0376 - accuracy: 0.9853 - val_loss: 0.2736 - val_accuracy: 0.9272
# Epoch 25/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0371 - accuracy: 0.9868 - val_loss: 0.4830 - val_accuracy: 0.8498
# Epoch 26/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0359 - accuracy: 0.9874 - val_loss: 0.3705 - val_accuracy: 0.9118
# Epoch 27/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0337 - accuracy: 0.9866 - val_loss: 0.3826 - val_accuracy: 0.9079
# Epoch 28/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0248 - accuracy: 0.9915 - val_loss: 0.3907 - val_accuracy: 0.9187
# Epoch 29/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0238 - accuracy: 0.9911 - val_loss: 0.3677 - val_accuracy: 0.9102
# Epoch 30/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0249 - accuracy: 0.9897 - val_loss: 0.3951 - val_accuracy: 0.9195
# Epoch 31/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0293 - accuracy: 0.9888 - val_loss: 0.3967 - val_accuracy: 0.9017
# Epoch 32/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0244 - accuracy: 0.9915 - val_loss: 0.3345 - val_accuracy: 0.9272
# Epoch 33/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0257 - accuracy: 0.9925 - val_loss: 0.4376 - val_accuracy: 0.9149
# Epoch 34/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0249 - accuracy: 0.9921 - val_loss: 0.3816 - val_accuracy: 0.9125
# Epoch 35/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0196 - accuracy: 0.9930 - val_loss: 0.4453 - val_accuracy: 0.9017
# Epoch 36/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0258 - accuracy: 0.9917 - val_loss: 0.3470 - val_accuracy: 0.9288
# Epoch 37/40
# 162/162 [==============================] - 22s 135ms/step - loss: 0.0175 - accuracy: 0.9948 - val_loss: 0.4542 - val_accuracy: 0.9164
# Epoch 38/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0236 - accuracy: 0.9921 - val_loss: 0.5017 - val_accuracy: 0.9133
# Epoch 39/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0235 - accuracy: 0.9923 - val_loss: 0.4927 - val_accuracy: 0.8978
# Epoch 40/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0183 - accuracy: 0.9930 - val_loss: 0.3872 - val_accuracy: 0.9218
#
# FOLD: 2
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/40
# 162/162 [==============================] - 50s 142ms/step - loss: 0.6056 - accuracy: 0.7478 - val_loss: 0.5023 - val_accuracy: 0.7477
# Epoch 2/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.3539 - accuracy: 0.8519 - val_loss: 0.5498 - val_accuracy: 0.7755
# Epoch 3/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.2720 - accuracy: 0.8907 - val_loss: 0.3086 - val_accuracy: 0.8622
# Epoch 4/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.2288 - accuracy: 0.9028 - val_loss: 0.2760 - val_accuracy: 0.8901
# Epoch 5/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1942 - accuracy: 0.9230 - val_loss: 0.3212 - val_accuracy: 0.8638
# Epoch 6/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1697 - accuracy: 0.9352 - val_loss: 0.2467 - val_accuracy: 0.9048
# Epoch 7/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1385 - accuracy: 0.9454 - val_loss: 0.3103 - val_accuracy: 0.8885
# Epoch 8/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1294 - accuracy: 0.9508 - val_loss: 0.6671 - val_accuracy: 0.7717
# Epoch 9/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1172 - accuracy: 0.9549 - val_loss: 0.9562 - val_accuracy: 0.7639
# Epoch 10/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1054 - accuracy: 0.9570 - val_loss: 0.2701 - val_accuracy: 0.8909
# Epoch 11/40
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0849 - accuracy: 0.9706 - val_loss: 0.3194 - val_accuracy: 0.8909
# Epoch 12/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0759 - accuracy: 0.9716 - val_loss: 0.4067 - val_accuracy: 0.8661
# Epoch 13/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0624 - accuracy: 0.9770 - val_loss: 0.2305 - val_accuracy: 0.9149
# Epoch 14/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0670 - accuracy: 0.9760 - val_loss: 0.5823 - val_accuracy: 0.8297
# Epoch 15/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0597 - accuracy: 0.9779 - val_loss: 0.3036 - val_accuracy: 0.9087
# Epoch 16/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0469 - accuracy: 0.9828 - val_loss: 0.3463 - val_accuracy: 0.8676
# Epoch 17/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0475 - accuracy: 0.9828 - val_loss: 0.3676 - val_accuracy: 0.8901
# Epoch 18/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0470 - accuracy: 0.9814 - val_loss: 0.5463 - val_accuracy: 0.8166
# Epoch 19/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0499 - accuracy: 0.9832 - val_loss: 0.2868 - val_accuracy: 0.9195
# Epoch 20/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0390 - accuracy: 0.9861 - val_loss: 0.3806 - val_accuracy: 0.8940
# Epoch 21/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0464 - accuracy: 0.9847 - val_loss: 0.3234 - val_accuracy: 0.9056
# Epoch 22/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0352 - accuracy: 0.9863 - val_loss: 0.5446 - val_accuracy: 0.8607
# Epoch 23/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0412 - accuracy: 0.9851 - val_loss: 0.3054 - val_accuracy: 0.9187
# Epoch 24/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0227 - accuracy: 0.9921 - val_loss: 1.5196 - val_accuracy: 0.7384
# Epoch 25/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0327 - accuracy: 0.9884 - val_loss: 0.3085 - val_accuracy: 0.9002
# Epoch 26/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0265 - accuracy: 0.9897 - val_loss: 0.2685 - val_accuracy: 0.9125
# Epoch 27/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0302 - accuracy: 0.9866 - val_loss: 0.3015 - val_accuracy: 0.9265
# Epoch 28/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0222 - accuracy: 0.9926 - val_loss: 0.5861 - val_accuracy: 0.8793
# Epoch 29/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 0.2944 - val_accuracy: 0.9211
# Epoch 30/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0246 - accuracy: 0.9926 - val_loss: 0.2749 - val_accuracy: 0.9187
# Epoch 31/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0182 - accuracy: 0.9928 - val_loss: 0.5957 - val_accuracy: 0.8839
# Epoch 32/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0265 - accuracy: 0.9907 - val_loss: 0.2977 - val_accuracy: 0.9195
# Epoch 33/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0185 - accuracy: 0.9932 - val_loss: 0.4260 - val_accuracy: 0.8963
# Epoch 34/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0272 - accuracy: 0.9903 - val_loss: 0.4610 - val_accuracy: 0.9149
# Epoch 35/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0205 - accuracy: 0.9928 - val_loss: 0.3279 - val_accuracy: 0.9133
# Epoch 36/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0213 - accuracy: 0.9925 - val_loss: 0.4646 - val_accuracy: 0.9164
# Epoch 37/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0137 - accuracy: 0.9959 - val_loss: 0.4812 - val_accuracy: 0.9110
# Epoch 38/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0216 - accuracy: 0.9925 - val_loss: 0.4480 - val_accuracy: 0.9002
# Epoch 39/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.4797 - val_accuracy: 0.9195
# Epoch 40/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0150 - accuracy: 0.9954 - val_loss: 0.5059 - val_accuracy: 0.9149
#
# FOLD: 3
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/40
# 162/162 [==============================] - 50s 141ms/step - loss: 0.6454 - accuracy: 0.7422 - val_loss: 0.6340 - val_accuracy: 0.6943
# Epoch 2/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.4276 - accuracy: 0.8229 - val_loss: 0.6940 - val_accuracy: 0.7121
# Epoch 3/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.3111 - accuracy: 0.8682 - val_loss: 0.6198 - val_accuracy: 0.7523
# Epoch 4/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2501 - accuracy: 0.9011 - val_loss: 0.4009 - val_accuracy: 0.8359
# Epoch 5/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2136 - accuracy: 0.9125 - val_loss: 0.2686 - val_accuracy: 0.8963
# Epoch 6/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1844 - accuracy: 0.9245 - val_loss: 0.3739 - val_accuracy: 0.8514
# Epoch 7/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1639 - accuracy: 0.9352 - val_loss: 0.3109 - val_accuracy: 0.8769
# Epoch 8/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1459 - accuracy: 0.9460 - val_loss: 0.3863 - val_accuracy: 0.8537
# Epoch 9/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1204 - accuracy: 0.9526 - val_loss: 0.2689 - val_accuracy: 0.9017
# Epoch 10/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1060 - accuracy: 0.9601 - val_loss: 0.4257 - val_accuracy: 0.8576
# Epoch 11/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1055 - accuracy: 0.9601 - val_loss: 0.3144 - val_accuracy: 0.8947
# Epoch 12/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0846 - accuracy: 0.9673 - val_loss: 0.4590 - val_accuracy: 0.8777
# Epoch 13/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0737 - accuracy: 0.9706 - val_loss: 0.3879 - val_accuracy: 0.8924
# Epoch 14/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0546 - accuracy: 0.9799 - val_loss: 0.5156 - val_accuracy: 0.8483
# Epoch 15/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0642 - accuracy: 0.9762 - val_loss: 0.3878 - val_accuracy: 0.8932
# Epoch 16/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0632 - accuracy: 0.9770 - val_loss: 0.3433 - val_accuracy: 0.9025
# Epoch 17/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0485 - accuracy: 0.9805 - val_loss: 0.2934 - val_accuracy: 0.9156
# Epoch 18/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0462 - accuracy: 0.9835 - val_loss: 0.3257 - val_accuracy: 0.9211
# Epoch 19/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0445 - accuracy: 0.9863 - val_loss: 0.4429 - val_accuracy: 0.8885
# Epoch 20/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0422 - accuracy: 0.9855 - val_loss: 0.5056 - val_accuracy: 0.8916
# Epoch 21/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0472 - accuracy: 0.9816 - val_loss: 0.3904 - val_accuracy: 0.8785
# Epoch 22/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0288 - accuracy: 0.9905 - val_loss: 0.3960 - val_accuracy: 0.9102
# Epoch 23/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0371 - accuracy: 0.9847 - val_loss: 0.3173 - val_accuracy: 0.9172
# Epoch 24/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0326 - accuracy: 0.9868 - val_loss: 0.3932 - val_accuracy: 0.9102
# Epoch 25/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0339 - accuracy: 0.9886 - val_loss: 0.3897 - val_accuracy: 0.9203
# Epoch 26/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0250 - accuracy: 0.9907 - val_loss: 0.3083 - val_accuracy: 0.9172
# Epoch 27/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0219 - accuracy: 0.9930 - val_loss: 0.3285 - val_accuracy: 0.9303
# Epoch 28/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0283 - accuracy: 0.9911 - val_loss: 0.3692 - val_accuracy: 0.9040
# Epoch 29/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0283 - accuracy: 0.9909 - val_loss: 0.3748 - val_accuracy: 0.9087
# Epoch 30/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0161 - accuracy: 0.9942 - val_loss: 0.4379 - val_accuracy: 0.9110
# Epoch 31/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0281 - accuracy: 0.9895 - val_loss: 0.3926 - val_accuracy: 0.9025
# Epoch 32/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0296 - accuracy: 0.9895 - val_loss: 0.3471 - val_accuracy: 0.9241
# Epoch 33/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0182 - accuracy: 0.9930 - val_loss: 0.3754 - val_accuracy: 0.9156
# Epoch 34/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0251 - accuracy: 0.9917 - val_loss: 0.3314 - val_accuracy: 0.9334
# Epoch 35/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0171 - accuracy: 0.9932 - val_loss: 0.3541 - val_accuracy: 0.9249
# Epoch 36/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 0.4138 - val_accuracy: 0.9234
# Epoch 37/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0176 - accuracy: 0.9930 - val_loss: 0.4081 - val_accuracy: 0.9226
# Epoch 38/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0130 - accuracy: 0.9957 - val_loss: 0.5292 - val_accuracy: 0.9156
# Epoch 39/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0213 - accuracy: 0.9938 - val_loss: 0.4548 - val_accuracy: 0.9118
# Epoch 40/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0159 - accuracy: 0.9942 - val_loss: 0.3631 - val_accuracy: 0.9265
#
# FOLD: 4
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/40
# 162/162 [==============================] - 50s 141ms/step - loss: 0.6499 - accuracy: 0.7399 - val_loss: 0.8005 - val_accuracy: 0.6285
# Epoch 2/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3963 - accuracy: 0.8293 - val_loss: 0.9419 - val_accuracy: 0.6006
# Epoch 3/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2954 - accuracy: 0.8767 - val_loss: 0.3743 - val_accuracy: 0.8475
# Epoch 4/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2525 - accuracy: 0.8970 - val_loss: 0.5359 - val_accuracy: 0.7593
# Epoch 5/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2208 - accuracy: 0.9079 - val_loss: 0.2963 - val_accuracy: 0.8862
# Epoch 6/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1779 - accuracy: 0.9301 - val_loss: 0.5531 - val_accuracy: 0.7655
# Epoch 7/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1734 - accuracy: 0.9296 - val_loss: 0.2728 - val_accuracy: 0.8947
# Epoch 8/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1573 - accuracy: 0.9365 - val_loss: 0.3883 - val_accuracy: 0.8630
# Epoch 9/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1250 - accuracy: 0.9489 - val_loss: 0.2681 - val_accuracy: 0.8978
# Epoch 10/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1196 - accuracy: 0.9545 - val_loss: 0.4117 - val_accuracy: 0.8437
# Epoch 11/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1097 - accuracy: 0.9611 - val_loss: 0.2725 - val_accuracy: 0.8994
# Epoch 12/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0980 - accuracy: 0.9646 - val_loss: 0.2866 - val_accuracy: 0.8901
# Epoch 13/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0728 - accuracy: 0.9729 - val_loss: 0.9138 - val_accuracy: 0.8073
# Epoch 14/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0804 - accuracy: 0.9690 - val_loss: 0.3402 - val_accuracy: 0.8847
# Epoch 15/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0567 - accuracy: 0.9787 - val_loss: 0.2818 - val_accuracy: 0.9102
# Epoch 16/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0565 - accuracy: 0.9787 - val_loss: 0.8786 - val_accuracy: 0.8050
# Epoch 17/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0572 - accuracy: 0.9770 - val_loss: 0.4304 - val_accuracy: 0.8622
# Epoch 18/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0488 - accuracy: 0.9805 - val_loss: 0.3023 - val_accuracy: 0.9118
# Epoch 19/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0480 - accuracy: 0.9830 - val_loss: 0.4352 - val_accuracy: 0.8522
# Epoch 20/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0416 - accuracy: 0.9843 - val_loss: 0.4406 - val_accuracy: 0.8878
# Epoch 21/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0404 - accuracy: 0.9876 - val_loss: 0.5896 - val_accuracy: 0.8460
# Epoch 22/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0310 - accuracy: 0.9895 - val_loss: 0.2979 - val_accuracy: 0.9257
# Epoch 23/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0241 - accuracy: 0.9907 - val_loss: 0.5583 - val_accuracy: 0.8568
# Epoch 24/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0412 - accuracy: 0.9847 - val_loss: 0.2334 - val_accuracy: 0.9327
# Epoch 25/40
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0237 - accuracy: 0.9907 - val_loss: 0.5482 - val_accuracy: 0.8731
# Epoch 26/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0261 - accuracy: 0.9907 - val_loss: 0.3328 - val_accuracy: 0.9110
# Epoch 27/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0282 - accuracy: 0.9907 - val_loss: 0.3234 - val_accuracy: 0.9025
# Epoch 28/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0265 - accuracy: 0.9909 - val_loss: 1.0521 - val_accuracy: 0.8096
# Epoch 29/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0241 - accuracy: 0.9899 - val_loss: 0.3355 - val_accuracy: 0.9172
# Epoch 30/40
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0227 - accuracy: 0.9936 - val_loss: 0.2903 - val_accuracy: 0.9249
# Epoch 31/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 0.3448 - val_accuracy: 0.9257
# Epoch 32/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0254 - accuracy: 0.9907 - val_loss: 0.3361 - val_accuracy: 0.9063
# Epoch 33/40
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0320 - accuracy: 0.9895 - val_loss: 0.3204 - val_accuracy: 0.9257
# Epoch 34/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0126 - accuracy: 0.9969 - val_loss: 0.3228 - val_accuracy: 0.9303
# Epoch 35/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0164 - accuracy: 0.9944 - val_loss: 0.3574 - val_accuracy: 0.9211
# Epoch 36/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0110 - accuracy: 0.9959 - val_loss: 0.3820 - val_accuracy: 0.9087
# Epoch 37/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0217 - accuracy: 0.9932 - val_loss: 0.5406 - val_accuracy: 0.8816
# Epoch 38/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0213 - accuracy: 0.9932 - val_loss: 0.3611 - val_accuracy: 0.9280
# Epoch 39/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0219 - accuracy: 0.9923 - val_loss: 0.3991 - val_accuracy: 0.8963
# Epoch 40/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0149 - accuracy: 0.9948 - val_loss: 0.3149 - val_accuracy: 0.9211
#
# FOLD: 5
# Found 5168 validated image filenames belonging to 2 classes.
# Found 1291 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/40
# 162/162 [==============================] - 50s 143ms/step - loss: 0.5917 - accuracy: 0.7521 - val_loss: 1.2140 - val_accuracy: 0.5763
# Epoch 2/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.3653 - accuracy: 0.8450 - val_loss: 1.3534 - val_accuracy: 0.5732
# Epoch 3/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.2794 - accuracy: 0.8824 - val_loss: 0.5380 - val_accuracy: 0.7769
# Epoch 4/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.2474 - accuracy: 0.9002 - val_loss: 0.3404 - val_accuracy: 0.8482
# Epoch 5/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1977 - accuracy: 0.9189 - val_loss: 0.4161 - val_accuracy: 0.8567
# Epoch 6/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1883 - accuracy: 0.9269 - val_loss: 0.3718 - val_accuracy: 0.8644
# Epoch 7/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1676 - accuracy: 0.9321 - val_loss: 0.2732 - val_accuracy: 0.8985
# Epoch 8/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1321 - accuracy: 0.9501 - val_loss: 0.2949 - val_accuracy: 0.8985
# Epoch 9/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1188 - accuracy: 0.9547 - val_loss: 0.2794 - val_accuracy: 0.8978
# Epoch 10/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.1080 - accuracy: 0.9594 - val_loss: 0.2384 - val_accuracy: 0.9109
# Epoch 11/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1056 - accuracy: 0.9607 - val_loss: 0.6003 - val_accuracy: 0.7878
# Epoch 12/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0894 - accuracy: 0.9652 - val_loss: 0.5930 - val_accuracy: 0.8350
# Epoch 13/40
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0728 - accuracy: 0.9735 - val_loss: 0.4034 - val_accuracy: 0.9032
# Epoch 14/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0613 - accuracy: 0.9758 - val_loss: 0.4042 - val_accuracy: 0.8885
# Epoch 15/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0681 - accuracy: 0.9760 - val_loss: 0.2934 - val_accuracy: 0.9194
# Epoch 16/40
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0480 - accuracy: 0.9822 - val_loss: 0.3557 - val_accuracy: 0.8978
# Epoch 17/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0524 - accuracy: 0.9814 - val_loss: 0.3693 - val_accuracy: 0.8970
# Epoch 18/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0425 - accuracy: 0.9843 - val_loss: 0.2912 - val_accuracy: 0.9078
# Epoch 19/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0496 - accuracy: 0.9795 - val_loss: 0.3103 - val_accuracy: 0.9179
# Epoch 20/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0381 - accuracy: 0.9866 - val_loss: 0.6100 - val_accuracy: 0.8552
# Epoch 21/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0470 - accuracy: 0.9843 - val_loss: 0.4093 - val_accuracy: 0.8753
# Epoch 22/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0259 - accuracy: 0.9901 - val_loss: 0.3977 - val_accuracy: 0.8784
# Epoch 23/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0458 - accuracy: 0.9865 - val_loss: 0.3373 - val_accuracy: 0.9016
# Epoch 24/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0356 - accuracy: 0.9878 - val_loss: 0.2866 - val_accuracy: 0.9210
# Epoch 25/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0305 - accuracy: 0.9890 - val_loss: 0.4308 - val_accuracy: 0.8978
# Epoch 26/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0274 - accuracy: 0.9921 - val_loss: 0.5587 - val_accuracy: 0.8490
# Epoch 27/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0262 - accuracy: 0.9905 - val_loss: 0.3970 - val_accuracy: 0.9163
# Epoch 28/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0261 - accuracy: 0.9928 - val_loss: 0.4953 - val_accuracy: 0.9016
# Epoch 29/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0263 - accuracy: 0.9905 - val_loss: 0.4255 - val_accuracy: 0.9125
# Epoch 30/40
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0291 - accuracy: 0.9896 - val_loss: 0.6503 - val_accuracy: 0.8908
# Epoch 31/40
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0198 - accuracy: 0.9934 - val_loss: 0.3591 - val_accuracy: 0.9218
# Epoch 32/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0201 - accuracy: 0.9936 - val_loss: 0.2803 - val_accuracy: 0.9380
# Epoch 33/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0218 - accuracy: 0.9932 - val_loss: 0.4195 - val_accuracy: 0.9218
# Epoch 34/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0140 - accuracy: 0.9959 - val_loss: 0.4557 - val_accuracy: 0.9109
# Epoch 35/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0179 - accuracy: 0.9930 - val_loss: 0.3278 - val_accuracy: 0.9373
# Epoch 36/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0253 - accuracy: 0.9917 - val_loss: 0.3682 - val_accuracy: 0.9373
# Epoch 37/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0184 - accuracy: 0.9936 - val_loss: 0.3715 - val_accuracy: 0.9311
# Epoch 38/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0143 - accuracy: 0.9946 - val_loss: 0.4174 - val_accuracy: 0.9171
# Epoch 39/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0123 - accuracy: 0.9950 - val_loss: 0.4837 - val_accuracy: 0.9140
# Epoch 40/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0157 - accuracy: 0.9946 - val_loss: 0.4978 - val_accuracy: 0.9140

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_training(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3
# FOLD: 4
# FOLD: 5

# %%
test_batch_size = 32
validation_accuracies = []

for fold, model in enumerate(model_list):
    print(f'\nFOLD: {fold+1}')
    train_score = model.evaluate(train_data[fold], batch_size=test_batch_size, verbose= 1)
    valid_score = model.evaluate(val_data[fold], batch_size=test_batch_size, verbose= 1)

    print('-' * 20)
    print("Train Loss: ", train_score[0])
    print("Train Accuracy: ", train_score[1])
    print('-' * 20)
    print("Validation Loss: ", valid_score[0])
    print("Validation Accuracy: ", valid_score[1])
    print('-' * 20)

    validation_accuracies.append(valid_score[1])
    hours = duration_list[fold]['hours']
    minutes = duration_list[fold]['minutes']
    seconds = duration_list[fold]['seconds']

    msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
    print(msg)

best_fold = np.argmax(validation_accuracies)
best_model = model_list[best_fold]
print ("Best Fold berada pada : ",best_fold)
print (best_model)
# Out:
# FOLD: 1
# 162/162 [==============================] - 16s 97ms/step - loss: 0.0054 - accuracy: 0.9988
# 41/41 [==============================] - 4s 89ms/step - loss: 0.3872 - accuracy: 0.9218
# --------------------
# Train Loss:  0.005439906381070614
# Train Accuracy:  0.9988387823104858
# --------------------
# Validation Loss:  0.3872249722480774
# Validation Accuracy:  0.9218266010284424
# --------------------
# training elapsed time was 0.0 hours, 14.0 minutes, 58.32 seconds)
#
# FOLD: 2
# 162/162 [==============================] - 16s 95ms/step - loss: 0.0082 - accuracy: 0.9979
# 41/41 [==============================] - 4s 86ms/step - loss: 0.5059 - accuracy: 0.9149
# --------------------
# Train Loss:  0.00821643602102995
# Train Accuracy:  0.9978711009025574
# --------------------
# Validation Loss:  0.5059354901313782
# Validation Accuracy:  0.9148606657981873
# --------------------
# training elapsed time was 0.0 hours, 14.0 minutes, 48.70 seconds)
#
# FOLD: 3
# 162/162 [==============================] - 16s 96ms/step - loss: 0.0024 - accuracy: 0.9994
# 41/41 [==============================] - 4s 90ms/step - loss: 0.3631 - accuracy: 0.9265
# --------------------
# Train Loss:  0.002372055547311902
# Train Accuracy:  0.9994193911552429
# --------------------
# Validation Loss:  0.36310309171676636
# Validation Accuracy:  0.9264705777168274
# --------------------
# training elapsed time was 0.0 hours, 14.0 minutes, 43.54 seconds)
#
# FOLD: 4
# 162/162 [==============================] - 16s 97ms/step - loss: 0.0171 - accuracy: 0.9944
# 41/41 [==============================] - 4s 91ms/step - loss: 0.3149 - accuracy: 0.9211
# --------------------
# Train Loss:  0.017105955630540848
# Train Accuracy:  0.9943874478340149
# --------------------
# Validation Loss:  0.3149314224720001
# Validation Accuracy:  0.9210526347160339
# --------------------
# training elapsed time was 0.0 hours, 14.0 minutes, 48.43 seconds)
#
# FOLD: 5
# 162/162 [==============================] - 16s 100ms/step - loss: 0.0360 - accuracy: 0.9876
# 41/41 [==============================] - 4s 91ms/step - loss: 0.4978 - accuracy: 0.9140
# --------------------
# Train Loss:  0.03599000349640846
# Train Accuracy:  0.9876161217689514
# --------------------
# Validation Loss:  0.4977954030036926
# Validation Accuracy:  0.9140201210975647
# --------------------
# training elapsed time was 0.0 hours, 14.0 minutes, 51.39 seconds)
# Best Fold berada pada :  2
# <keras.src.engine.sequential.Sequential object at 0x79c7680bd8d0>

# %%
preds = best_model.predict_generator(test_gen, verbose=1)
y_pred = np.argmax(preds, axis=1)
print(y_pred)
# Out:
# 51/51 [==============================] - 6s 91ms/step
# [0 0 1 ... 1 1 1]

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

cm = confusion_matrix(test_gen.classes, y_pred)
plot_confusion_matrix(cm= cm, classes= classes, title = 'Confusion Matrix')

    # Classification report
print(classification_report(test_gen.classes, y_pred, target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#          all       0.95      0.85      0.90       808
#          hem       0.87      0.95      0.91       807
#
#     accuracy                           0.90      1615
#    macro avg       0.91      0.90      0.90      1615
# weighted avg       0.91      0.90      0.90      1615

# %%
from sklearn import metrics


y_prob = []

for data in preds:
    y_prob.append(data[1])

fpr, tpr, thresholds = metrics.roc_curve(test_gen.classes, y_prob)
auc = metrics.auc(fpr, tpr)

plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], 'k--')  # Garis diagonal untuk klasifikasi acak
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()
