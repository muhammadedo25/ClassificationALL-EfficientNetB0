# %%
# import system libs
import glob
import os
import time
import shutil
import pathlib
import itertools

# import data handling tools
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import resample
from sklearn.model_selection import KFold

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.activations import relu
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
def undersample_dataframe(df, target_column):
    # Menghitung jumlah sampel untuk setiap kelas
    label_counts = df[target_column].value_counts()

    # Menentukan jumlah sampel terkecil pada kelas
    min_label_count = label_counts.min()

    # Inisialisasi dataframe kosong untuk menyimpan sampel undersampled
    undersampled_df = pd.DataFrame()

    # Melakukan undersampling pada setiap kelas
    for label in label_counts.index:
        # Memilih sampel acak dengan jumlah yang sesuai dari setiap kelas
        undersampled_class_df = resample(
            df[df[target_column] == label],
            replace=False,  # Tidak mengganti sampel yang dipilih
            n_samples=min_label_count,  # Jumlah sampel yang sesuai
            random_state=42  # Seed untuk reproduksi
        )

        # Menyimpan sampel undersampled
        undersampled_df = pd.concat([undersampled_df, undersampled_class_df])

    return undersampled_df

# %%
# Function that create dataframe for train, and test data
def create_df(df_fix):
    # train dataframe
    df = df_fix
    strat = df['labels']
    train_df, test_df = train_test_split(df, train_size=0.8, shuffle=True, random_state=42, stratify=strat)

    return train_df, test_df

# %%
def create_model_data_test (test_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR atau Grayscale
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    ts_length = len(test_df)
    test_batch_size = 32

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    ts_gen = ImageDataGenerator(preprocessing_function= scalar)

    test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= False, batch_size= test_batch_size)

    return test_gen

# %%
def create_model_data_train (train_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    tr_gen = ImageDataGenerator(preprocessing_function= scalar, horizontal_flip= True)

    train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    return train_gen

# %%
def create_model_data_valid (valid_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR atau Grayscale
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    ts_gen = ImageDataGenerator(preprocessing_function= scalar)

    valid_gen = ts_gen.flow_from_dataframe( valid_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    return valid_gen

# %%
def show_images(gen):

    # mengembalikan kelas, gambar yang akan ditampilkan
    g_dict = gen.class_indices        # defines dictionary {'class': index}
    classes = list(g_dict.keys())     # mendefinisikan list dari dictionary keys (classes), classes names : string
    images, labels = next(gen)        # dapatkan ukuran batch size samples dari generator

    # menghitung banyaknya sample yang ditampilkan
    length = len(labels)        # panjang dari batch size
    sample = min(length, 25)    # cek jika sample kurang dari 25 gambar

    plt.figure(figsize= (20, 20))

    for i in range(sample):
        plt.subplot(5, 5, i + 1)
        image = images[i] / 255       # menskalakan data dalam rentang (0 - 255)
        plt.imshow(image)
        index = np.argmax(labels[i])  # dapatkan index gambar
        class_name = classes[index]   # dapatkan class dari gambar
        plt.title(class_name, color= 'blue', fontsize= 12)
        plt.axis('off')
    plt.show()

# %%
GCS_PATH = '/content/drive/MyDrive/Leukemia/'

# Membaca Data Train

train_dataset_0_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_0/all/*.bmp')
train_dataset_0_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_0/hem/*.bmp')
train_dataset_1_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_1/all/*.bmp')
train_dataset_1_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_1/hem/*.bmp')
train_dataset_2_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_2/all/*.bmp')
train_dataset_2_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_2/hem/*.bmp')

# Merging data:-
A=[]
H=[]

A.extend(train_dataset_0_all)
A.extend(train_dataset_1_all)
A.extend(train_dataset_2_all)

H.extend(train_dataset_0_hem)
H.extend(train_dataset_1_hem)
H.extend(train_dataset_2_hem)

print('Data Train')
print(len(A))
print(len(H))

# Membuat labels :-
Label_A = [1]*len(A)
Label_H = [0]*len(H)

# Convert ke pandas dataframe untuk memudahkan akses:-
A.extend(H)
Label_A.extend(Label_H)
df = pd.DataFrame({'filepaths':A, 'labels':Label_A})
df = df.sample(frac=1).reset_index(drop=True)

# Include Validation data
test_data=pd.read_csv(GCS_PATH + 'C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data_labels.csv')

at = test_data[test_data['labels'] == 1]
ht = test_data[test_data['labels'] == 0]

test_PATH = GCS_PATH + 'C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/'
ATL = [test_PATH +  i for i in list(at.new_names)]
HTL = [test_PATH +  i for i in list(ht.new_names)]

TA=[]
TH=[]

TA.extend(ATL)
TH.extend(HTL)

print('\nData Test')
print(len(TA))
print(len(TH))

# Membuat Tabel
Label_TA = [1]*len(TA)
Label_TH = [0]*len(TH)

# Convert ke Pandas DataFrame
TA.extend(TH)
Label_TA.extend(Label_TH)
tdf = pd.DataFrame({'filepaths':TA, 'labels':Label_TA})
tdf = tdf.sample(frac=1).reset_index(drop=True)
# Out:
# Data Train
# 7272
# 3389
#
# Data Test
# 1219
# 648

# %%
df_combined = pd.concat([df, tdf], ignore_index=True)
df_combined['labels'] = df_combined['labels'].replace({1: 'all', 0: 'hem'})
df_combined
# Out:
#                                                filepaths labels
# 0      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 1      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 2      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 3      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 4      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# ...                                                  ...    ...
# 12523  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 12524  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 12525  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 12526  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 12527  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
#
# [12528 rows x 2 columns]

# %%
df_fix = undersample_dataframe(df_combined, 'labels')
df_fix = df_fix.reset_index(drop=True)
df_fix
# Out:
#                                               filepaths labels
# 0     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 1     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 2     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 3     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 4     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# ...                                                 ...    ...
# 8069  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8070  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8071  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8072  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8073  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
#
# [8074 rows x 2 columns]

# %%
print("Total number of images in the dataset: ", len(df_fix))

label_count = df_fix['labels'].value_counts()
print(label_count)
# Out:
# Total number of images in the dataset:  8074
# all    4037
# hem    4037
# Name: labels, dtype: int64

# %%
# Get splitted data
train_df, test_df = create_df(df_fix)

# Get Generators
batch_size = 32
test_gen = create_model_data_test(test_df, batch_size)
# Out:
# Found 1615 validated image filenames belonging to 2 classes.

# %%
show_images(test_gen)

# %%
def plot_training(hist):
    '''
    Function ini mengambil model pelatihan dan riwayat plot akurasi dan loss dengan epoch terbaik di keduanya.
    '''

    # Define variables yang dibutuhkan
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training dan Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training dan Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
def plot_confusion_matrix(cm, classes, title= 'Confusion Matrix', cmap= plt.cm.Blues):
    '''
    Function ini digunakan untuk memplot confusion matrix menggunakan sklearn package.
    '''

    plt.figure(figsize= (10, 10))
    plt.imshow(cm, interpolation= 'nearest', cmap= cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation= 45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')

# %%
def efficientNet_B0():
    # Create Model Structure
    img_size = (224, 224)
    channels = 3
    img_shape = (img_size[0], img_size[1], channels)

    base_model = tf.keras.applications.efficientnet.EfficientNetB0(include_top= False, weights= 'imagenet', input_shape= img_shape, pooling= 'max')

    model = Sequential([
        base_model,
        BatchNormalization(),
        Dense(256, activation=relu),
        Dropout(0.2),
        Dense(2, activation='sigmoid')
    ])
    model.compile(Adamax(learning_rate= 0.0001), loss= 'binary_crossentropy', metrics= ['accuracy'])

    return model

# %%
history_list, model_list = [], []
train_data, val_data  = [], []
duration_list = []
kfold=5
epochs=30
fold = 1

kf = KFold(n_splits=kfold, shuffle=True, random_state=42)
fold_indices = kf.split(train_df)

for fold, (train_index, val_index) in enumerate(fold_indices):
    print(f'\nFOLD: {fold+1}')

    # Inisialisasi DataFrame baru untuk menyimpan data pelatihan dan validation
    train_subset_df = pd.DataFrame()
    valid_subset_df = pd.DataFrame()

    fold_train_df = train_df.iloc[train_index] # Bagi data menjadi set pelatihan dan validasi
    fold_valid_df = train_df.iloc[val_index]

    # Tambahkan data pelatihan dan validation pada lipatan ini ke DataFrame baru
    train_subset_df = pd.concat([train_subset_df, fold_train_df], ignore_index=True)
    valid_subset_df = pd.concat([valid_subset_df, fold_valid_df], ignore_index=True)

    train_gen = create_model_data_train(train_subset_df, batch_size) # generate data train dan valid
    valid_gen = create_model_data_valid(valid_subset_df, batch_size)

    K.clear_session()
    print('\nMODEL SUMMARY:')
    model = efficientNet_B0()
    model.summary()

    print('\nFITTING MODEL:')
    start_time = time.time() # mencatat waktu mulai
    history = model.fit(x= train_gen, epochs= epochs, verbose= 1,
                    validation_data= valid_gen, validation_steps= None, shuffle= False)


    stop_time = time.time()
    tr_duration = stop_time - start_time
    hours = tr_duration // 3600
    minutes = (tr_duration - (hours * 3600)) // 60
    seconds = tr_duration - ((hours * 3600) + (minutes * 60))
    sum_duration = {
        'hours' : hours,
        'minutes' : minutes,
        'seconds' : seconds
    }

    duration_list.append(sum_duration)

    history_list.append(history)
    model_list.append(model)

    train_data.append(train_gen)
    val_data.append(valid_gen)
# Out:
# FOLD: 1
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/30
# 162/162 [==============================] - 49s 138ms/step - loss: 0.6815 - accuracy: 0.6820 - val_loss: 0.5985 - val_accuracy: 0.6904
# Epoch 2/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.5533 - accuracy: 0.7445 - val_loss: 0.5180 - val_accuracy: 0.7663
# Epoch 3/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.4782 - accuracy: 0.7763 - val_loss: 0.4463 - val_accuracy: 0.7933
# Epoch 4/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.4294 - accuracy: 0.7968 - val_loss: 0.4020 - val_accuracy: 0.8212
# Epoch 5/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3900 - accuracy: 0.8233 - val_loss: 0.4011 - val_accuracy: 0.8204
# Epoch 6/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3702 - accuracy: 0.8351 - val_loss: 0.4162 - val_accuracy: 0.8344
# Epoch 7/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3388 - accuracy: 0.8550 - val_loss: 0.3737 - val_accuracy: 0.8367
# Epoch 8/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3194 - accuracy: 0.8554 - val_loss: 0.3681 - val_accuracy: 0.8475
# Epoch 9/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2911 - accuracy: 0.8713 - val_loss: 0.3725 - val_accuracy: 0.8553
# Epoch 10/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2746 - accuracy: 0.8827 - val_loss: 0.3623 - val_accuracy: 0.8584
# Epoch 11/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2502 - accuracy: 0.9003 - val_loss: 0.3762 - val_accuracy: 0.8506
# Epoch 12/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2315 - accuracy: 0.9050 - val_loss: 0.3659 - val_accuracy: 0.8591
# Epoch 13/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2111 - accuracy: 0.9141 - val_loss: 0.3903 - val_accuracy: 0.8615
# Epoch 14/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2005 - accuracy: 0.9201 - val_loss: 0.3496 - val_accuracy: 0.8669
# Epoch 15/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1917 - accuracy: 0.9191 - val_loss: 0.3638 - val_accuracy: 0.8754
# Epoch 16/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1689 - accuracy: 0.9307 - val_loss: 0.4299 - val_accuracy: 0.8591
# Epoch 17/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1820 - accuracy: 0.9220 - val_loss: 0.3820 - val_accuracy: 0.8684
# Epoch 18/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1590 - accuracy: 0.9361 - val_loss: 0.3444 - val_accuracy: 0.8831
# Epoch 19/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1379 - accuracy: 0.9441 - val_loss: 0.3634 - val_accuracy: 0.8854
# Epoch 20/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1404 - accuracy: 0.9402 - val_loss: 0.3616 - val_accuracy: 0.8808
# Epoch 21/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1253 - accuracy: 0.9501 - val_loss: 0.4062 - val_accuracy: 0.8731
# Epoch 22/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1208 - accuracy: 0.9537 - val_loss: 0.4222 - val_accuracy: 0.8769
# Epoch 23/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1119 - accuracy: 0.9557 - val_loss: 0.4798 - val_accuracy: 0.8646
# Epoch 24/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1196 - accuracy: 0.9537 - val_loss: 0.3753 - val_accuracy: 0.8862
# Epoch 25/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1024 - accuracy: 0.9596 - val_loss: 0.4136 - val_accuracy: 0.8824
# Epoch 26/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0903 - accuracy: 0.9665 - val_loss: 0.3834 - val_accuracy: 0.8893
# Epoch 27/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0933 - accuracy: 0.9673 - val_loss: 0.4365 - val_accuracy: 0.8800
# Epoch 28/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0920 - accuracy: 0.9648 - val_loss: 0.4396 - val_accuracy: 0.8816
# Epoch 29/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0889 - accuracy: 0.9671 - val_loss: 0.4407 - val_accuracy: 0.8870
# Epoch 30/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0854 - accuracy: 0.9669 - val_loss: 0.4153 - val_accuracy: 0.8847
#
# FOLD: 2
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/30
# 162/162 [==============================] - 49s 139ms/step - loss: 0.6621 - accuracy: 0.6867 - val_loss: 0.7777 - val_accuracy: 0.5844
# Epoch 2/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.5064 - accuracy: 0.7585 - val_loss: 0.5326 - val_accuracy: 0.7531
# Epoch 3/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.4823 - accuracy: 0.7879 - val_loss: 0.5165 - val_accuracy: 0.7693
# Epoch 4/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.4315 - accuracy: 0.8086 - val_loss: 0.4461 - val_accuracy: 0.7995
# Epoch 5/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3982 - accuracy: 0.8187 - val_loss: 0.4236 - val_accuracy: 0.8042
# Epoch 6/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3420 - accuracy: 0.8454 - val_loss: 0.4295 - val_accuracy: 0.8181
# Epoch 7/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3318 - accuracy: 0.8568 - val_loss: 0.4490 - val_accuracy: 0.8142
# Epoch 8/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3078 - accuracy: 0.8655 - val_loss: 0.4321 - val_accuracy: 0.8150
# Epoch 9/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2736 - accuracy: 0.8852 - val_loss: 0.3552 - val_accuracy: 0.8498
# Epoch 10/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2581 - accuracy: 0.8967 - val_loss: 0.3964 - val_accuracy: 0.8382
# Epoch 11/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2480 - accuracy: 0.8955 - val_loss: 0.3710 - val_accuracy: 0.8491
# Epoch 12/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2381 - accuracy: 0.9003 - val_loss: 0.3469 - val_accuracy: 0.8584
# Epoch 13/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2082 - accuracy: 0.9154 - val_loss: 0.3462 - val_accuracy: 0.8622
# Epoch 14/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2038 - accuracy: 0.9158 - val_loss: 0.3764 - val_accuracy: 0.8483
# Epoch 15/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1994 - accuracy: 0.9176 - val_loss: 0.3242 - val_accuracy: 0.8754
# Epoch 16/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1764 - accuracy: 0.9278 - val_loss: 0.3664 - val_accuracy: 0.8522
# Epoch 17/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1653 - accuracy: 0.9357 - val_loss: 0.3620 - val_accuracy: 0.8676
# Epoch 18/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1599 - accuracy: 0.9371 - val_loss: 0.3307 - val_accuracy: 0.8731
# Epoch 19/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1431 - accuracy: 0.9412 - val_loss: 0.3401 - val_accuracy: 0.8731
# Epoch 20/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1234 - accuracy: 0.9489 - val_loss: 0.3966 - val_accuracy: 0.8599
# Epoch 21/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1283 - accuracy: 0.9474 - val_loss: 0.3963 - val_accuracy: 0.8615
# Epoch 22/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1193 - accuracy: 0.9505 - val_loss: 0.4145 - val_accuracy: 0.8622
# Epoch 23/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1135 - accuracy: 0.9563 - val_loss: 0.3251 - val_accuracy: 0.8785
# Epoch 24/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1085 - accuracy: 0.9572 - val_loss: 0.3182 - val_accuracy: 0.8808
# Epoch 25/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1093 - accuracy: 0.9599 - val_loss: 0.3744 - val_accuracy: 0.8816
# Epoch 26/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0997 - accuracy: 0.9632 - val_loss: 0.4460 - val_accuracy: 0.8607
# Epoch 27/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0985 - accuracy: 0.9605 - val_loss: 0.3525 - val_accuracy: 0.8824
# Epoch 28/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0818 - accuracy: 0.9702 - val_loss: 0.4497 - val_accuracy: 0.8591
# Epoch 29/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0881 - accuracy: 0.9681 - val_loss: 0.3650 - val_accuracy: 0.8901
# Epoch 30/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0792 - accuracy: 0.9716 - val_loss: 0.3373 - val_accuracy: 0.8947
#
# FOLD: 3
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/30
# 162/162 [==============================] - 48s 138ms/step - loss: 0.6678 - accuracy: 0.6845 - val_loss: 0.6949 - val_accuracy: 0.6006
# Epoch 2/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.5283 - accuracy: 0.7505 - val_loss: 0.5723 - val_accuracy: 0.7438
# Epoch 3/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.4645 - accuracy: 0.7931 - val_loss: 0.4781 - val_accuracy: 0.7802
# Epoch 4/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.4103 - accuracy: 0.8138 - val_loss: 0.4308 - val_accuracy: 0.8011
# Epoch 5/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3952 - accuracy: 0.8206 - val_loss: 0.4519 - val_accuracy: 0.8042
# Epoch 6/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3641 - accuracy: 0.8423 - val_loss: 0.4002 - val_accuracy: 0.8235
# Epoch 7/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3325 - accuracy: 0.8543 - val_loss: 0.4137 - val_accuracy: 0.8181
# Epoch 8/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2984 - accuracy: 0.8744 - val_loss: 0.4062 - val_accuracy: 0.8320
# Epoch 9/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2869 - accuracy: 0.8757 - val_loss: 0.4394 - val_accuracy: 0.8289
# Epoch 10/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.2549 - accuracy: 0.8930 - val_loss: 0.4434 - val_accuracy: 0.8313
# Epoch 11/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2435 - accuracy: 0.8996 - val_loss: 0.3633 - val_accuracy: 0.8506
# Epoch 12/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2293 - accuracy: 0.9019 - val_loss: 0.3901 - val_accuracy: 0.8483
# Epoch 13/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2146 - accuracy: 0.9087 - val_loss: 0.3898 - val_accuracy: 0.8483
# Epoch 14/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1984 - accuracy: 0.9179 - val_loss: 0.4420 - val_accuracy: 0.8351
# Epoch 15/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1876 - accuracy: 0.9224 - val_loss: 0.3819 - val_accuracy: 0.8615
# Epoch 16/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1741 - accuracy: 0.9332 - val_loss: 0.4058 - val_accuracy: 0.8560
# Epoch 17/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1590 - accuracy: 0.9354 - val_loss: 0.3747 - val_accuracy: 0.8630
# Epoch 18/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.1548 - accuracy: 0.9381 - val_loss: 0.3836 - val_accuracy: 0.8630
# Epoch 19/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1457 - accuracy: 0.9383 - val_loss: 0.3689 - val_accuracy: 0.8731
# Epoch 20/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1379 - accuracy: 0.9448 - val_loss: 0.5043 - val_accuracy: 0.8421
# Epoch 21/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1304 - accuracy: 0.9493 - val_loss: 0.3844 - val_accuracy: 0.8692
# Epoch 22/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1249 - accuracy: 0.9487 - val_loss: 0.3797 - val_accuracy: 0.8591
# Epoch 23/30
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1206 - accuracy: 0.9532 - val_loss: 0.5297 - val_accuracy: 0.8344
# Epoch 24/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1069 - accuracy: 0.9599 - val_loss: 0.4755 - val_accuracy: 0.8560
# Epoch 25/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.1052 - accuracy: 0.9623 - val_loss: 0.4394 - val_accuracy: 0.8646
# Epoch 26/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1037 - accuracy: 0.9586 - val_loss: 0.4600 - val_accuracy: 0.8622
# Epoch 27/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0977 - accuracy: 0.9594 - val_loss: 0.4786 - val_accuracy: 0.8630
# Epoch 28/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.0919 - accuracy: 0.9638 - val_loss: 0.3882 - val_accuracy: 0.8731
# Epoch 29/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0862 - accuracy: 0.9659 - val_loss: 0.4558 - val_accuracy: 0.8715
# Epoch 30/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0786 - accuracy: 0.9706 - val_loss: 0.3994 - val_accuracy: 0.8808
#
# FOLD: 4
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/30
# 162/162 [==============================] - 49s 140ms/step - loss: 0.6931 - accuracy: 0.6807 - val_loss: 0.8178 - val_accuracy: 0.5774
# Epoch 2/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.5260 - accuracy: 0.7527 - val_loss: 0.5929 - val_accuracy: 0.6966
# Epoch 3/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.4758 - accuracy: 0.7852 - val_loss: 0.5217 - val_accuracy: 0.7755
# Epoch 4/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.4278 - accuracy: 0.8024 - val_loss: 0.4326 - val_accuracy: 0.8050
# Epoch 5/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3980 - accuracy: 0.8194 - val_loss: 0.3972 - val_accuracy: 0.8297
# Epoch 6/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3682 - accuracy: 0.8370 - val_loss: 0.4455 - val_accuracy: 0.8065
# Epoch 7/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3497 - accuracy: 0.8452 - val_loss: 0.4195 - val_accuracy: 0.8367
# Epoch 8/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3171 - accuracy: 0.8622 - val_loss: 0.4290 - val_accuracy: 0.8189
# Epoch 9/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3128 - accuracy: 0.8636 - val_loss: 0.3796 - val_accuracy: 0.8560
# Epoch 10/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2714 - accuracy: 0.8816 - val_loss: 0.4592 - val_accuracy: 0.8228
# Epoch 11/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2588 - accuracy: 0.8870 - val_loss: 0.3618 - val_accuracy: 0.8669
# Epoch 12/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2386 - accuracy: 0.8996 - val_loss: 0.3622 - val_accuracy: 0.8622
# Epoch 13/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2357 - accuracy: 0.9075 - val_loss: 0.3423 - val_accuracy: 0.8692
# Epoch 14/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2204 - accuracy: 0.9063 - val_loss: 0.3540 - val_accuracy: 0.8529
# Epoch 15/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1995 - accuracy: 0.9148 - val_loss: 0.3363 - val_accuracy: 0.8653
# Epoch 16/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1851 - accuracy: 0.9266 - val_loss: 0.3583 - val_accuracy: 0.8676
# Epoch 17/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1836 - accuracy: 0.9237 - val_loss: 0.3323 - val_accuracy: 0.8731
# Epoch 18/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1774 - accuracy: 0.9290 - val_loss: 0.3284 - val_accuracy: 0.8762
# Epoch 19/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1536 - accuracy: 0.9383 - val_loss: 0.3371 - val_accuracy: 0.8785
# Epoch 20/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1449 - accuracy: 0.9419 - val_loss: 0.3291 - val_accuracy: 0.8854
# Epoch 21/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1487 - accuracy: 0.9421 - val_loss: 0.3291 - val_accuracy: 0.8932
# Epoch 22/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.1333 - accuracy: 0.9441 - val_loss: 0.3757 - val_accuracy: 0.8824
# Epoch 23/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.1303 - accuracy: 0.9456 - val_loss: 0.3319 - val_accuracy: 0.8878
# Epoch 24/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.1192 - accuracy: 0.9514 - val_loss: 0.3509 - val_accuracy: 0.8816
# Epoch 25/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.1176 - accuracy: 0.9553 - val_loss: 0.3344 - val_accuracy: 0.8916
# Epoch 26/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1080 - accuracy: 0.9547 - val_loss: 0.4592 - val_accuracy: 0.8568
# Epoch 27/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1032 - accuracy: 0.9603 - val_loss: 0.3439 - val_accuracy: 0.8909
# Epoch 28/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0926 - accuracy: 0.9636 - val_loss: 0.4280 - val_accuracy: 0.8707
# Epoch 29/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1010 - accuracy: 0.9599 - val_loss: 0.3377 - val_accuracy: 0.9009
# Epoch 30/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0936 - accuracy: 0.9634 - val_loss: 0.5284 - val_accuracy: 0.8622
#
# FOLD: 5
# Found 5168 validated image filenames belonging to 2 classes.
# Found 1291 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/30
# 162/162 [==============================] - 49s 140ms/step - loss: 0.6539 - accuracy: 0.6904 - val_loss: 0.7090 - val_accuracy: 0.6305
# Epoch 2/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.5291 - accuracy: 0.7585 - val_loss: 0.5160 - val_accuracy: 0.7699
# Epoch 3/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.4620 - accuracy: 0.7873 - val_loss: 0.4461 - val_accuracy: 0.8002
# Epoch 4/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.4106 - accuracy: 0.8065 - val_loss: 0.4003 - val_accuracy: 0.8257
# Epoch 5/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3776 - accuracy: 0.8340 - val_loss: 0.4074 - val_accuracy: 0.8226
# Epoch 6/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3536 - accuracy: 0.8440 - val_loss: 0.3906 - val_accuracy: 0.8311
# Epoch 7/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.3310 - accuracy: 0.8595 - val_loss: 0.3876 - val_accuracy: 0.8311
# Epoch 8/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3041 - accuracy: 0.8696 - val_loss: 0.4000 - val_accuracy: 0.8226
# Epoch 9/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2893 - accuracy: 0.8727 - val_loss: 0.3607 - val_accuracy: 0.8474
# Epoch 10/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2581 - accuracy: 0.8914 - val_loss: 0.3953 - val_accuracy: 0.8397
# Epoch 11/30
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2536 - accuracy: 0.8928 - val_loss: 0.3240 - val_accuracy: 0.8652
# Epoch 12/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2202 - accuracy: 0.9083 - val_loss: 0.3611 - val_accuracy: 0.8590
# Epoch 13/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2187 - accuracy: 0.9125 - val_loss: 0.3320 - val_accuracy: 0.8629
# Epoch 14/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2010 - accuracy: 0.9209 - val_loss: 0.3831 - val_accuracy: 0.8497
# Epoch 15/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1996 - accuracy: 0.9199 - val_loss: 0.3171 - val_accuracy: 0.8753
# Epoch 16/30
# 162/162 [==============================] - 21s 128ms/step - loss: 0.1685 - accuracy: 0.9325 - val_loss: 0.3278 - val_accuracy: 0.8699
# Epoch 17/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1724 - accuracy: 0.9272 - val_loss: 0.3764 - val_accuracy: 0.8575
# Epoch 18/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1534 - accuracy: 0.9387 - val_loss: 0.3371 - val_accuracy: 0.8776
# Epoch 19/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1426 - accuracy: 0.9445 - val_loss: 0.3251 - val_accuracy: 0.8815
# Epoch 20/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1341 - accuracy: 0.9462 - val_loss: 0.4063 - val_accuracy: 0.8637
# Epoch 21/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1321 - accuracy: 0.9468 - val_loss: 0.3259 - val_accuracy: 0.8768
# Epoch 22/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1241 - accuracy: 0.9526 - val_loss: 0.3973 - val_accuracy: 0.8737
# Epoch 23/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1136 - accuracy: 0.9586 - val_loss: 0.3500 - val_accuracy: 0.8807
# Epoch 24/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1175 - accuracy: 0.9541 - val_loss: 0.3271 - val_accuracy: 0.8892
# Epoch 25/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1010 - accuracy: 0.9609 - val_loss: 0.3453 - val_accuracy: 0.8815
# Epoch 26/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1001 - accuracy: 0.9648 - val_loss: 0.3337 - val_accuracy: 0.8869
# Epoch 27/30
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0930 - accuracy: 0.9667 - val_loss: 0.4856 - val_accuracy: 0.8513
# Epoch 28/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0983 - accuracy: 0.9603 - val_loss: 0.3485 - val_accuracy: 0.8869
# Epoch 29/30
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0815 - accuracy: 0.9710 - val_loss: 0.4001 - val_accuracy: 0.8714
# Epoch 30/30
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0793 - accuracy: 0.9702 - val_loss: 0.3556 - val_accuracy: 0.8908

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_training(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3
# FOLD: 4
# FOLD: 5

# %%
test_batch_size = 32
validation_accuracies = []

for fold, model in enumerate(model_list):
    print(f'\nFOLD: {fold+1}')
    train_score = model.evaluate(train_data[fold], batch_size=test_batch_size, verbose= 1)
    valid_score = model.evaluate(val_data[fold], batch_size=test_batch_size, verbose= 1)

    print('-' * 20)
    print("Train Loss: ", train_score[0])
    print("Train Accuracy: ", train_score[1])
    print('-' * 20)
    print("Validation Loss: ", valid_score[0])
    print("Validation Accuracy: ", valid_score[1])
    print('-' * 20)

    validation_accuracies.append(valid_score[1])
    hours = duration_list[fold]['hours']
    minutes = duration_list[fold]['minutes']
    seconds = duration_list[fold]['seconds']

    msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
    print(msg)

best_fold = np.argmax(validation_accuracies)
best_model = model_list[best_fold]
print ("Best Fold berada pada : ",best_fold)
print (best_model)
# Out:
# FOLD: 1
# 162/162 [==============================] - 16s 91ms/step - loss: 0.0152 - accuracy: 0.9977
# 41/41 [==============================] - 4s 91ms/step - loss: 0.4153 - accuracy: 0.8847
# --------------------
# Train Loss:  0.015192156657576561
# Train Accuracy:  0.9976775646209717
# --------------------
# Validation Loss:  0.4153343737125397
# Validation Accuracy:  0.8846749067306519
# --------------------
# training elapsed time was 0.0 hours, 11.0 minutes, 1.55 seconds)
#
# FOLD: 2
# 162/162 [==============================] - 16s 92ms/step - loss: 0.0128 - accuracy: 0.9975
# 41/41 [==============================] - 3s 83ms/step - loss: 0.3373 - accuracy: 0.8947
# --------------------
# Train Loss:  0.01280517503619194
# Train Accuracy:  0.997484028339386
# --------------------
# Validation Loss:  0.3373282253742218
# Validation Accuracy:  0.8947368264198303
# --------------------
# training elapsed time was 0.0 hours, 11.0 minutes, 3.19 seconds)
#
# FOLD: 3
# 162/162 [==============================] - 15s 91ms/step - loss: 0.0151 - accuracy: 0.9977
# 41/41 [==============================] - 4s 90ms/step - loss: 0.3994 - accuracy: 0.8808
# --------------------
# Train Loss:  0.015086776576936245
# Train Accuracy:  0.9976775646209717
# --------------------
# Validation Loss:  0.3993528485298157
# Validation Accuracy:  0.8808049559593201
# --------------------
# training elapsed time was 0.0 hours, 10.0 minutes, 58.41 seconds)
#
# FOLD: 4
# 162/162 [==============================] - 15s 92ms/step - loss: 0.1157 - accuracy: 0.9518
# 41/41 [==============================] - 4s 86ms/step - loss: 0.5284 - accuracy: 0.8622
# --------------------
# Train Loss:  0.11569023132324219
# Train Accuracy:  0.9518095850944519
# --------------------
# Validation Loss:  0.5284479856491089
# Validation Accuracy:  0.8622291088104248
# --------------------
# training elapsed time was 0.0 hours, 11.0 minutes, 0.44 seconds)
#
# FOLD: 5
# 162/162 [==============================] - 15s 90ms/step - loss: 0.0137 - accuracy: 0.9985
# 41/41 [==============================] - 4s 86ms/step - loss: 0.3556 - accuracy: 0.8908
# --------------------
# Train Loss:  0.013705745339393616
# Train Accuracy:  0.9984520077705383
# --------------------
# Validation Loss:  0.3556017577648163
# Validation Accuracy:  0.890782356262207
# --------------------
# training elapsed time was 0.0 hours, 11.0 minutes, 1.58 seconds)
# Best Fold berada pada :  1
# <keras.src.engine.sequential.Sequential object at 0x79c79984e7d0>

# %%
preds = best_model.predict_generator(test_gen, verbose=1)
y_pred = np.argmax(preds, axis=1)
print(y_pred)
# Out:
# 51/51 [==============================] - 6s 86ms/step
# [0 0 1 ... 1 1 1]

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

cm = confusion_matrix(test_gen.classes, y_pred)
plot_confusion_matrix(cm= cm, classes= classes, title = 'Confusion Matrix')

    # Classification report
print(classification_report(test_gen.classes, y_pred, target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#          all       0.88      0.92      0.90       808
#          hem       0.91      0.87      0.89       807
#
#     accuracy                           0.89      1615
#    macro avg       0.89      0.89      0.89      1615
# weighted avg       0.89      0.89      0.89      1615

# %%
from sklearn import metrics


y_prob = []

for data in preds:
    y_prob.append(data[1])

fpr, tpr, thresholds = metrics.roc_curve(test_gen.classes, y_prob)
auc = metrics.auc(fpr, tpr)

plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], 'k--')  # Garis diagonal untuk klasifikasi acak
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()
