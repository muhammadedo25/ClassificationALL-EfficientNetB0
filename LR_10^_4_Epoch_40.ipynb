# %%
# import system libs
import glob
import os
import time
import shutil
import pathlib
import itertools

# import data handling tools
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import resample
from sklearn.model_selection import KFold

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.activations import relu
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
def undersample_dataframe(df, target_column):
    # Menghitung jumlah sampel untuk setiap kelas
    label_counts = df[target_column].value_counts()

    # Menentukan jumlah sampel terkecil pada kelas
    min_label_count = label_counts.min()

    # Inisialisasi dataframe kosong untuk menyimpan sampel undersampled
    undersampled_df = pd.DataFrame()

    # Melakukan undersampling pada setiap kelas
    for label in label_counts.index:
        # Memilih sampel acak dengan jumlah yang sesuai dari setiap kelas
        undersampled_class_df = resample(
            df[df[target_column] == label],
            replace=False,  # Tidak mengganti sampel yang dipilih
            n_samples=min_label_count,  # Jumlah sampel yang sesuai
            random_state=42  # Seed untuk reproduksi
        )

        # Menyimpan sampel undersampled
        undersampled_df = pd.concat([undersampled_df, undersampled_class_df])

    return undersampled_df

# %%
# Function that create dataframe for train, and test data
def create_df(df_fix):
    # train dataframe
    df = df_fix
    strat = df['labels']
    train_df, test_df = train_test_split(df, train_size=0.8, shuffle=True, random_state=42, stratify=strat)

    return train_df, test_df

# %%
def create_model_data_test (test_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR atau Grayscale
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    ts_length = len(test_df)
    test_batch_size = 32

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    ts_gen = ImageDataGenerator(preprocessing_function= scalar)

    test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= False, batch_size= test_batch_size)

    return test_gen

# %%
def create_model_data_train (train_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    tr_gen = ImageDataGenerator(preprocessing_function= scalar, horizontal_flip= True)

    train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    return train_gen

# %%
def create_model_data_valid (valid_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR atau Grayscale
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    ts_gen = ImageDataGenerator(preprocessing_function= scalar)

    valid_gen = ts_gen.flow_from_dataframe( valid_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    return valid_gen

# %%
def show_images(gen):

    # mengembalikan kelas, gambar yang akan ditampilkan
    g_dict = gen.class_indices        # defines dictionary {'class': index}
    classes = list(g_dict.keys())     # mendefinisikan list dari dictionary keys (classes), classes names : string
    images, labels = next(gen)        # dapatkan ukuran batch size samples dari generator

    # menghitung banyaknya sample yang ditampilkan
    length = len(labels)        # panjang dari batch size
    sample = min(length, 25)    # cek jika sample kurang dari 25 gambar

    plt.figure(figsize= (20, 20))

    for i in range(sample):
        plt.subplot(5, 5, i + 1)
        image = images[i] / 255       # menskalakan data dalam rentang (0 - 255)
        plt.imshow(image)
        index = np.argmax(labels[i])  # dapatkan index gambar
        class_name = classes[index]   # dapatkan class dari gambar
        plt.title(class_name, color= 'blue', fontsize= 12)
        plt.axis('off')
    plt.show()

# %%
GCS_PATH = '/content/drive/MyDrive/Leukemia/'

# Membaca Data Train

train_dataset_0_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_0/all/*.bmp')
train_dataset_0_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_0/hem/*.bmp')
train_dataset_1_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_1/all/*.bmp')
train_dataset_1_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_1/hem/*.bmp')
train_dataset_2_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_2/all/*.bmp')
train_dataset_2_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_2/hem/*.bmp')

# Merging data:-
A=[]
H=[]

A.extend(train_dataset_0_all)
A.extend(train_dataset_1_all)
A.extend(train_dataset_2_all)

H.extend(train_dataset_0_hem)
H.extend(train_dataset_1_hem)
H.extend(train_dataset_2_hem)

print('Data Train')
print(len(A))
print(len(H))

# Membuat labels :-
Label_A = [1]*len(A)
Label_H = [0]*len(H)

# Convert ke pandas dataframe untuk memudahkan akses:-
A.extend(H)
Label_A.extend(Label_H)
df = pd.DataFrame({'filepaths':A, 'labels':Label_A})
df = df.sample(frac=1).reset_index(drop=True)

# Include Validation data
test_data=pd.read_csv(GCS_PATH + 'C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data_labels.csv')

at = test_data[test_data['labels'] == 1]
ht = test_data[test_data['labels'] == 0]

test_PATH = GCS_PATH + 'C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/'
ATL = [test_PATH +  i for i in list(at.new_names)]
HTL = [test_PATH +  i for i in list(ht.new_names)]

TA=[]
TH=[]

TA.extend(ATL)
TH.extend(HTL)

print('\nData Test')
print(len(TA))
print(len(TH))

# Membuat Tabel
Label_TA = [1]*len(TA)
Label_TH = [0]*len(TH)

# Convert ke Pandas DataFrame
TA.extend(TH)
Label_TA.extend(Label_TH)
tdf = pd.DataFrame({'filepaths':TA, 'labels':Label_TA})
tdf = tdf.sample(frac=1).reset_index(drop=True)
# Out:
# Data Train
# 7272
# 3389
#
# Data Test
# 1219
# 648

# %%
df_combined = pd.concat([df, tdf], ignore_index=True)
df_combined['labels'] = df_combined['labels'].replace({1: 'all', 0: 'hem'})
df_combined
# Out:
#                                                filepaths labels
# 0      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 1      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 2      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 3      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 4      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# ...                                                  ...    ...
# 12523  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 12524  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 12525  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 12526  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 12527  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
#
# [12528 rows x 2 columns]

# %%
df_fix = undersample_dataframe(df_combined, 'labels')
df_fix = df_fix.reset_index(drop=True)
df_fix
# Out:
#                                               filepaths labels
# 0     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 1     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 2     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 3     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 4     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# ...                                                 ...    ...
# 8069  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8070  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8071  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8072  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8073  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
#
# [8074 rows x 2 columns]

# %%
print("Total number of images in the dataset: ", len(df_fix))

label_count = df_fix['labels'].value_counts()
print(label_count)
# Out:
# Total number of images in the dataset:  8074
# all    4037
# hem    4037
# Name: labels, dtype: int64

# %%
# Get splitted data
train_df, test_df = create_df(df_fix)

# Get Generators
batch_size = 32
test_gen = create_model_data_test(test_df, batch_size)
# Out:
# Found 1615 validated image filenames belonging to 2 classes.

# %%
show_images(test_gen)

# %%
def plot_training(hist):
    '''
    Function ini mengambil model pelatihan dan riwayat plot akurasi dan loss dengan epoch terbaik di keduanya.
    '''

    # Define variables yang dibutuhkan
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training dan Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training dan Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
def plot_confusion_matrix(cm, classes, title= 'Confusion Matrix', cmap= plt.cm.Blues):
    '''
    Function ini digunakan untuk memplot confusion matrix menggunakan sklearn package.
    '''

    plt.figure(figsize= (10, 10))
    plt.imshow(cm, interpolation= 'nearest', cmap= cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation= 45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')

# %%
def efficientNet_B0():
    # Create Model Structure
    img_size = (224, 224)
    channels = 3
    img_shape = (img_size[0], img_size[1], channels)

    base_model = tf.keras.applications.efficientnet.EfficientNetB0(include_top= False, weights= 'imagenet', input_shape= img_shape, pooling= 'max')

    model = Sequential([
        base_model,
        BatchNormalization(),
        Dense(256, activation=relu),
        Dropout(0.2),
        Dense(2, activation='sigmoid')
    ])
    model.compile(Adamax(learning_rate= 0.0001), loss= 'binary_crossentropy', metrics= ['accuracy'])

    return model

# %%
history_list, model_list = [], []
train_data, val_data  = [], []
duration_list = []
kfold=5
epochs=40
fold = 1

kf = KFold(n_splits=kfold, shuffle=True, random_state=42)
fold_indices = kf.split(train_df)

for fold, (train_index, val_index) in enumerate(fold_indices):
    print(f'\nFOLD: {fold+1}')

    # Inisialisasi DataFrame baru untuk menyimpan data pelatihan dan validation
    train_subset_df = pd.DataFrame()
    valid_subset_df = pd.DataFrame()

    fold_train_df = train_df.iloc[train_index] # Bagi data menjadi set pelatihan dan validasi
    fold_valid_df = train_df.iloc[val_index]

    # Tambahkan data pelatihan dan validation pada lipatan ini ke DataFrame baru
    train_subset_df = pd.concat([train_subset_df, fold_train_df], ignore_index=True)
    valid_subset_df = pd.concat([valid_subset_df, fold_valid_df], ignore_index=True)

    train_gen = create_model_data_train(train_subset_df, batch_size) # generate data train dan valid
    valid_gen = create_model_data_valid(valid_subset_df, batch_size)

    K.clear_session()
    print('\nMODEL SUMMARY:')
    model = efficientNet_B0()
    model.summary()

    print('\nFITTING MODEL:')
    start_time = time.time() # mencatat waktu mulai
    history = model.fit(x= train_gen, epochs= epochs, verbose= 1,
                    validation_data= valid_gen, validation_steps= None, shuffle= False)


    stop_time = time.time()
    tr_duration = stop_time - start_time
    hours = tr_duration // 3600
    minutes = (tr_duration - (hours * 3600)) // 60
    seconds = tr_duration - ((hours * 3600) + (minutes * 60))
    sum_duration = {
        'hours' : hours,
        'minutes' : minutes,
        'seconds' : seconds
    }

    duration_list.append(sum_duration)

    history_list.append(history)
    model_list.append(model)

    train_data.append(train_gen)
    val_data.append(valid_gen)
# Out:
# FOLD: 1
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/40
# 162/162 [==============================] - 50s 144ms/step - loss: 0.6630 - accuracy: 0.6888 - val_loss: 0.7314 - val_accuracy: 0.5836
# Epoch 2/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.5405 - accuracy: 0.7449 - val_loss: 0.5196 - val_accuracy: 0.7624
# Epoch 3/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.4735 - accuracy: 0.7803 - val_loss: 0.5102 - val_accuracy: 0.7647
# Epoch 4/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.4388 - accuracy: 0.7981 - val_loss: 0.4034 - val_accuracy: 0.8351
# Epoch 5/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3977 - accuracy: 0.8204 - val_loss: 0.3975 - val_accuracy: 0.8204
# Epoch 6/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3513 - accuracy: 0.8415 - val_loss: 0.3864 - val_accuracy: 0.8398
# Epoch 7/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3327 - accuracy: 0.8543 - val_loss: 0.4917 - val_accuracy: 0.8119
# Epoch 8/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3072 - accuracy: 0.8696 - val_loss: 0.3581 - val_accuracy: 0.8452
# Epoch 9/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2886 - accuracy: 0.8769 - val_loss: 0.3862 - val_accuracy: 0.8584
# Epoch 10/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2641 - accuracy: 0.8872 - val_loss: 0.3467 - val_accuracy: 0.8576
# Epoch 11/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2490 - accuracy: 0.8934 - val_loss: 0.3548 - val_accuracy: 0.8615
# Epoch 12/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2242 - accuracy: 0.9087 - val_loss: 0.3408 - val_accuracy: 0.8692
# Epoch 13/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2178 - accuracy: 0.9094 - val_loss: 0.3817 - val_accuracy: 0.8646
# Epoch 14/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2074 - accuracy: 0.9172 - val_loss: 0.3318 - val_accuracy: 0.8700
# Epoch 15/40
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1933 - accuracy: 0.9214 - val_loss: 0.3403 - val_accuracy: 0.8769
# Epoch 16/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1744 - accuracy: 0.9309 - val_loss: 0.3222 - val_accuracy: 0.8824
# Epoch 17/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1627 - accuracy: 0.9323 - val_loss: 0.4247 - val_accuracy: 0.8553
# Epoch 18/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1536 - accuracy: 0.9417 - val_loss: 0.3208 - val_accuracy: 0.8738
# Epoch 19/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1406 - accuracy: 0.9435 - val_loss: 0.3888 - val_accuracy: 0.8824
# Epoch 20/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1444 - accuracy: 0.9427 - val_loss: 0.3704 - val_accuracy: 0.8800
# Epoch 21/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1324 - accuracy: 0.9483 - val_loss: 0.3237 - val_accuracy: 0.8940
# Epoch 22/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1301 - accuracy: 0.9520 - val_loss: 0.3443 - val_accuracy: 0.8854
# Epoch 23/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1204 - accuracy: 0.9487 - val_loss: 0.3357 - val_accuracy: 0.8940
# Epoch 24/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1061 - accuracy: 0.9582 - val_loss: 0.3427 - val_accuracy: 0.8916
# Epoch 25/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1101 - accuracy: 0.9568 - val_loss: 0.3236 - val_accuracy: 0.9009
# Epoch 26/40
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1063 - accuracy: 0.9586 - val_loss: 0.3458 - val_accuracy: 0.8955
# Epoch 27/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0969 - accuracy: 0.9628 - val_loss: 0.3650 - val_accuracy: 0.8870
# Epoch 28/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0866 - accuracy: 0.9683 - val_loss: 0.3511 - val_accuracy: 0.8940
# Epoch 29/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0762 - accuracy: 0.9725 - val_loss: 0.3402 - val_accuracy: 0.8986
# Epoch 30/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0878 - accuracy: 0.9667 - val_loss: 0.4316 - val_accuracy: 0.8754
# Epoch 31/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0772 - accuracy: 0.9702 - val_loss: 0.3356 - val_accuracy: 0.8978
# Epoch 32/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0757 - accuracy: 0.9712 - val_loss: 0.3387 - val_accuracy: 0.8978
# Epoch 33/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0696 - accuracy: 0.9745 - val_loss: 0.3492 - val_accuracy: 0.8971
# Epoch 34/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0697 - accuracy: 0.9721 - val_loss: 0.3756 - val_accuracy: 0.8940
# Epoch 35/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0732 - accuracy: 0.9731 - val_loss: 0.3567 - val_accuracy: 0.8978
# Epoch 36/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0650 - accuracy: 0.9766 - val_loss: 0.3964 - val_accuracy: 0.8932
# Epoch 37/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0602 - accuracy: 0.9775 - val_loss: 0.3591 - val_accuracy: 0.8932
# Epoch 38/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0562 - accuracy: 0.9791 - val_loss: 0.3801 - val_accuracy: 0.8955
# Epoch 39/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0511 - accuracy: 0.9814 - val_loss: 0.3911 - val_accuracy: 0.8963
# Epoch 40/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0516 - accuracy: 0.9805 - val_loss: 0.4073 - val_accuracy: 0.8932
#
# FOLD: 2
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/40
# 162/162 [==============================] - 49s 141ms/step - loss: 0.6738 - accuracy: 0.6780 - val_loss: 0.6819 - val_accuracy: 0.6447
# Epoch 2/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.5278 - accuracy: 0.7596 - val_loss: 0.5132 - val_accuracy: 0.7539
# Epoch 3/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.4538 - accuracy: 0.7916 - val_loss: 0.5287 - val_accuracy: 0.7786
# Epoch 4/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.4391 - accuracy: 0.8014 - val_loss: 0.4572 - val_accuracy: 0.8057
# Epoch 5/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3978 - accuracy: 0.8227 - val_loss: 0.4390 - val_accuracy: 0.8104
# Epoch 6/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3591 - accuracy: 0.8357 - val_loss: 0.4367 - val_accuracy: 0.8228
# Epoch 7/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3321 - accuracy: 0.8581 - val_loss: 0.3912 - val_accuracy: 0.8282
# Epoch 8/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3109 - accuracy: 0.8665 - val_loss: 0.4876 - val_accuracy: 0.8034
# Epoch 9/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.2841 - accuracy: 0.8785 - val_loss: 0.3810 - val_accuracy: 0.8483
# Epoch 10/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2667 - accuracy: 0.8879 - val_loss: 0.4668 - val_accuracy: 0.8251
# Epoch 11/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2517 - accuracy: 0.9011 - val_loss: 0.3525 - val_accuracy: 0.8584
# Epoch 12/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2405 - accuracy: 0.8984 - val_loss: 0.3537 - val_accuracy: 0.8599
# Epoch 13/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2184 - accuracy: 0.9100 - val_loss: 0.3428 - val_accuracy: 0.8576
# Epoch 14/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2053 - accuracy: 0.9117 - val_loss: 0.7676 - val_accuracy: 0.7616
# Epoch 15/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1870 - accuracy: 0.9212 - val_loss: 0.3414 - val_accuracy: 0.8630
# Epoch 16/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1819 - accuracy: 0.9245 - val_loss: 0.5042 - val_accuracy: 0.8212
# Epoch 17/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1619 - accuracy: 0.9356 - val_loss: 0.4548 - val_accuracy: 0.8382
# Epoch 18/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1575 - accuracy: 0.9356 - val_loss: 0.3231 - val_accuracy: 0.8731
# Epoch 19/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1492 - accuracy: 0.9365 - val_loss: 0.4544 - val_accuracy: 0.8406
# Epoch 20/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1425 - accuracy: 0.9416 - val_loss: 0.5912 - val_accuracy: 0.8173
# Epoch 21/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1262 - accuracy: 0.9520 - val_loss: 0.3255 - val_accuracy: 0.8878
# Epoch 22/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1235 - accuracy: 0.9528 - val_loss: 0.3383 - val_accuracy: 0.8777
# Epoch 23/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1234 - accuracy: 0.9536 - val_loss: 0.3294 - val_accuracy: 0.8901
# Epoch 24/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1092 - accuracy: 0.9599 - val_loss: 0.3285 - val_accuracy: 0.8932
# Epoch 25/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1074 - accuracy: 0.9592 - val_loss: 0.4599 - val_accuracy: 0.8591
# Epoch 26/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0938 - accuracy: 0.9665 - val_loss: 0.3589 - val_accuracy: 0.8947
# Epoch 27/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0993 - accuracy: 0.9601 - val_loss: 0.3587 - val_accuracy: 0.8847
# Epoch 28/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0861 - accuracy: 0.9686 - val_loss: 0.3921 - val_accuracy: 0.8824
# Epoch 29/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0852 - accuracy: 0.9683 - val_loss: 0.3199 - val_accuracy: 0.8971
# Epoch 30/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0835 - accuracy: 0.9673 - val_loss: 0.3735 - val_accuracy: 0.8932
# Epoch 31/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0852 - accuracy: 0.9673 - val_loss: 0.5094 - val_accuracy: 0.8584
# Epoch 32/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0778 - accuracy: 0.9714 - val_loss: 0.3375 - val_accuracy: 0.8940
# Epoch 33/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0720 - accuracy: 0.9745 - val_loss: 0.3522 - val_accuracy: 0.8947
# Epoch 34/40
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0716 - accuracy: 0.9729 - val_loss: 0.3427 - val_accuracy: 0.8986
# Epoch 35/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0685 - accuracy: 0.9737 - val_loss: 0.3409 - val_accuracy: 0.9048
# Epoch 36/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0655 - accuracy: 0.9739 - val_loss: 0.4435 - val_accuracy: 0.8839
# Epoch 37/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0642 - accuracy: 0.9770 - val_loss: 0.4318 - val_accuracy: 0.8785
# Epoch 38/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0650 - accuracy: 0.9741 - val_loss: 0.5626 - val_accuracy: 0.8584
# Epoch 39/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0547 - accuracy: 0.9822 - val_loss: 0.3849 - val_accuracy: 0.8940
# Epoch 40/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0575 - accuracy: 0.9779 - val_loss: 0.4317 - val_accuracy: 0.8862
#
# FOLD: 3
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/40
# 162/162 [==============================] - 49s 141ms/step - loss: 0.6953 - accuracy: 0.6787 - val_loss: 0.8305 - val_accuracy: 0.5697
# Epoch 2/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.5421 - accuracy: 0.7540 - val_loss: 0.5611 - val_accuracy: 0.7554
# Epoch 3/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.4714 - accuracy: 0.7840 - val_loss: 0.4803 - val_accuracy: 0.7926
# Epoch 4/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.4268 - accuracy: 0.8049 - val_loss: 0.4542 - val_accuracy: 0.8104
# Epoch 5/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.4019 - accuracy: 0.8262 - val_loss: 0.4975 - val_accuracy: 0.7964
# Epoch 6/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.3630 - accuracy: 0.8423 - val_loss: 0.4015 - val_accuracy: 0.8367
# Epoch 7/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3275 - accuracy: 0.8529 - val_loss: 0.4258 - val_accuracy: 0.8289
# Epoch 8/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3031 - accuracy: 0.8676 - val_loss: 0.4037 - val_accuracy: 0.8467
# Epoch 9/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2950 - accuracy: 0.8738 - val_loss: 0.4387 - val_accuracy: 0.8228
# Epoch 10/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2760 - accuracy: 0.8790 - val_loss: 0.3815 - val_accuracy: 0.8514
# Epoch 11/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2579 - accuracy: 0.8862 - val_loss: 0.4257 - val_accuracy: 0.8406
# Epoch 12/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2409 - accuracy: 0.8999 - val_loss: 0.3851 - val_accuracy: 0.8475
# Epoch 13/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2085 - accuracy: 0.9152 - val_loss: 0.3800 - val_accuracy: 0.8599
# Epoch 14/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2055 - accuracy: 0.9135 - val_loss: 0.3624 - val_accuracy: 0.8599
# Epoch 15/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1901 - accuracy: 0.9230 - val_loss: 0.3743 - val_accuracy: 0.8646
# Epoch 16/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1773 - accuracy: 0.9270 - val_loss: 0.4224 - val_accuracy: 0.8545
# Epoch 17/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1589 - accuracy: 0.9367 - val_loss: 0.3944 - val_accuracy: 0.8638
# Epoch 18/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1596 - accuracy: 0.9367 - val_loss: 0.3875 - val_accuracy: 0.8615
# Epoch 19/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1531 - accuracy: 0.9439 - val_loss: 0.3866 - val_accuracy: 0.8715
# Epoch 20/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1315 - accuracy: 0.9474 - val_loss: 0.3630 - val_accuracy: 0.8831
# Epoch 21/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1318 - accuracy: 0.9472 - val_loss: 0.3799 - val_accuracy: 0.8793
# Epoch 22/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1227 - accuracy: 0.9549 - val_loss: 0.4575 - val_accuracy: 0.8615
# Epoch 23/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1242 - accuracy: 0.9487 - val_loss: 0.4051 - val_accuracy: 0.8769
# Epoch 24/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.1105 - accuracy: 0.9559 - val_loss: 0.3679 - val_accuracy: 0.8754
# Epoch 25/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1039 - accuracy: 0.9578 - val_loss: 0.4315 - val_accuracy: 0.8731
# Epoch 26/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1009 - accuracy: 0.9626 - val_loss: 0.3721 - val_accuracy: 0.8885
# Epoch 27/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1032 - accuracy: 0.9597 - val_loss: 0.5174 - val_accuracy: 0.8460
# Epoch 28/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0917 - accuracy: 0.9690 - val_loss: 0.3703 - val_accuracy: 0.8839
# Epoch 29/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0961 - accuracy: 0.9625 - val_loss: 0.3929 - val_accuracy: 0.8707
# Epoch 30/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0794 - accuracy: 0.9706 - val_loss: 0.4003 - val_accuracy: 0.8808
# Epoch 31/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0735 - accuracy: 0.9716 - val_loss: 0.4154 - val_accuracy: 0.8816
# Epoch 32/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0773 - accuracy: 0.9696 - val_loss: 0.3860 - val_accuracy: 0.8831
# Epoch 33/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0842 - accuracy: 0.9681 - val_loss: 0.3910 - val_accuracy: 0.8731
# Epoch 34/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0758 - accuracy: 0.9717 - val_loss: 0.4246 - val_accuracy: 0.8824
# Epoch 35/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0673 - accuracy: 0.9750 - val_loss: 0.4431 - val_accuracy: 0.8785
# Epoch 36/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0585 - accuracy: 0.9791 - val_loss: 0.4768 - val_accuracy: 0.8754
# Epoch 37/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0697 - accuracy: 0.9745 - val_loss: 0.4222 - val_accuracy: 0.8870
# Epoch 38/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0653 - accuracy: 0.9745 - val_loss: 0.4305 - val_accuracy: 0.8824
# Epoch 39/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0600 - accuracy: 0.9775 - val_loss: 0.3926 - val_accuracy: 0.8924
# Epoch 40/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0581 - accuracy: 0.9781 - val_loss: 0.4466 - val_accuracy: 0.8793
#
# FOLD: 4
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/40
# 162/162 [==============================] - 49s 139ms/step - loss: 0.6596 - accuracy: 0.6874 - val_loss: 0.7776 - val_accuracy: 0.5759
# Epoch 2/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.5359 - accuracy: 0.7529 - val_loss: 0.5438 - val_accuracy: 0.7229
# Epoch 3/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.4821 - accuracy: 0.7734 - val_loss: 0.4709 - val_accuracy: 0.7817
# Epoch 4/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.4198 - accuracy: 0.8101 - val_loss: 0.4612 - val_accuracy: 0.7957
# Epoch 5/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.4040 - accuracy: 0.8161 - val_loss: 0.4222 - val_accuracy: 0.8289
# Epoch 6/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3502 - accuracy: 0.8398 - val_loss: 0.4298 - val_accuracy: 0.8243
# Epoch 7/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3400 - accuracy: 0.8502 - val_loss: 0.4433 - val_accuracy: 0.8289
# Epoch 8/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3060 - accuracy: 0.8670 - val_loss: 0.3713 - val_accuracy: 0.8483
# Epoch 9/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.2939 - accuracy: 0.8725 - val_loss: 0.3715 - val_accuracy: 0.8483
# Epoch 10/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2623 - accuracy: 0.8903 - val_loss: 0.3884 - val_accuracy: 0.8584
# Epoch 11/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2532 - accuracy: 0.8924 - val_loss: 0.3361 - val_accuracy: 0.8568
# Epoch 12/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2480 - accuracy: 0.8930 - val_loss: 0.3619 - val_accuracy: 0.8607
# Epoch 13/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2158 - accuracy: 0.9094 - val_loss: 0.3352 - val_accuracy: 0.8715
# Epoch 14/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1992 - accuracy: 0.9172 - val_loss: 0.4573 - val_accuracy: 0.8398
# Epoch 15/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1765 - accuracy: 0.9288 - val_loss: 0.3434 - val_accuracy: 0.8653
# Epoch 16/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1848 - accuracy: 0.9255 - val_loss: 0.3301 - val_accuracy: 0.8707
# Epoch 17/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1620 - accuracy: 0.9338 - val_loss: 0.3698 - val_accuracy: 0.8684
# Epoch 18/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1559 - accuracy: 0.9371 - val_loss: 0.3612 - val_accuracy: 0.8707
# Epoch 19/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1503 - accuracy: 0.9431 - val_loss: 0.3672 - val_accuracy: 0.8700
# Epoch 20/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.1464 - accuracy: 0.9435 - val_loss: 0.4046 - val_accuracy: 0.8692
# Epoch 21/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1329 - accuracy: 0.9476 - val_loss: 0.3206 - val_accuracy: 0.8862
# Epoch 22/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1276 - accuracy: 0.9505 - val_loss: 0.3306 - val_accuracy: 0.8839
# Epoch 23/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1186 - accuracy: 0.9536 - val_loss: 0.3116 - val_accuracy: 0.8947
# Epoch 24/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1040 - accuracy: 0.9601 - val_loss: 0.3289 - val_accuracy: 0.8916
# Epoch 25/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1089 - accuracy: 0.9582 - val_loss: 0.3239 - val_accuracy: 0.9002
# Epoch 26/40
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1035 - accuracy: 0.9586 - val_loss: 0.3947 - val_accuracy: 0.8839
# Epoch 27/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0968 - accuracy: 0.9636 - val_loss: 0.3330 - val_accuracy: 0.8978
# Epoch 28/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0933 - accuracy: 0.9638 - val_loss: 0.3898 - val_accuracy: 0.8862
# Epoch 29/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0788 - accuracy: 0.9750 - val_loss: 0.3712 - val_accuracy: 0.8885
# Epoch 30/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0832 - accuracy: 0.9696 - val_loss: 0.3364 - val_accuracy: 0.8986
# Epoch 31/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0768 - accuracy: 0.9712 - val_loss: 0.3055 - val_accuracy: 0.9048
# Epoch 32/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0702 - accuracy: 0.9750 - val_loss: 0.3235 - val_accuracy: 0.9094
# Epoch 33/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0656 - accuracy: 0.9756 - val_loss: 0.3368 - val_accuracy: 0.9118
# Epoch 34/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0628 - accuracy: 0.9764 - val_loss: 0.3399 - val_accuracy: 0.9048
# Epoch 35/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0674 - accuracy: 0.9729 - val_loss: 0.3660 - val_accuracy: 0.8978
# Epoch 36/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0614 - accuracy: 0.9785 - val_loss: 0.3584 - val_accuracy: 0.9079
# Epoch 37/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0598 - accuracy: 0.9801 - val_loss: 0.3314 - val_accuracy: 0.9025
# Epoch 38/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0510 - accuracy: 0.9810 - val_loss: 0.3502 - val_accuracy: 0.9087
# Epoch 39/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0669 - accuracy: 0.9748 - val_loss: 0.3233 - val_accuracy: 0.9125
# Epoch 40/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0570 - accuracy: 0.9793 - val_loss: 0.3450 - val_accuracy: 0.9094
#
# FOLD: 5
# Found 5168 validated image filenames belonging to 2 classes.
# Found 1291 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/40
# 162/162 [==============================] - 50s 140ms/step - loss: 0.6674 - accuracy: 0.6867 - val_loss: 0.7490 - val_accuracy: 0.6081
# Epoch 2/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.5276 - accuracy: 0.7558 - val_loss: 0.4848 - val_accuracy: 0.7730
# Epoch 3/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.4624 - accuracy: 0.7881 - val_loss: 0.4523 - val_accuracy: 0.7932
# Epoch 4/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.4301 - accuracy: 0.8073 - val_loss: 0.4457 - val_accuracy: 0.8141
# Epoch 5/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3841 - accuracy: 0.8330 - val_loss: 0.4156 - val_accuracy: 0.8187
# Epoch 6/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.3507 - accuracy: 0.8446 - val_loss: 0.3914 - val_accuracy: 0.8366
# Epoch 7/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3196 - accuracy: 0.8628 - val_loss: 0.3779 - val_accuracy: 0.8397
# Epoch 8/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3099 - accuracy: 0.8673 - val_loss: 0.3724 - val_accuracy: 0.8598
# Epoch 9/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2681 - accuracy: 0.8845 - val_loss: 0.3675 - val_accuracy: 0.8513
# Epoch 10/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2602 - accuracy: 0.8907 - val_loss: 0.3425 - val_accuracy: 0.8675
# Epoch 11/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2414 - accuracy: 0.8988 - val_loss: 0.3633 - val_accuracy: 0.8613
# Epoch 12/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.2350 - accuracy: 0.9019 - val_loss: 0.3535 - val_accuracy: 0.8598
# Epoch 13/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2209 - accuracy: 0.9079 - val_loss: 0.3485 - val_accuracy: 0.8637
# Epoch 14/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2016 - accuracy: 0.9195 - val_loss: 0.4228 - val_accuracy: 0.8590
# Epoch 15/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.2017 - accuracy: 0.9166 - val_loss: 0.3138 - val_accuracy: 0.8799
# Epoch 16/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1777 - accuracy: 0.9280 - val_loss: 0.3266 - val_accuracy: 0.8753
# Epoch 17/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1659 - accuracy: 0.9369 - val_loss: 0.3333 - val_accuracy: 0.8807
# Epoch 18/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1656 - accuracy: 0.9329 - val_loss: 0.3532 - val_accuracy: 0.8799
# Epoch 19/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1544 - accuracy: 0.9412 - val_loss: 0.4095 - val_accuracy: 0.8644
# Epoch 20/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1441 - accuracy: 0.9423 - val_loss: 0.3249 - val_accuracy: 0.8908
# Epoch 21/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1303 - accuracy: 0.9503 - val_loss: 0.3470 - val_accuracy: 0.8823
# Epoch 22/40
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1200 - accuracy: 0.9532 - val_loss: 0.3305 - val_accuracy: 0.8970
# Epoch 23/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1206 - accuracy: 0.9536 - val_loss: 0.3985 - val_accuracy: 0.8830
# Epoch 24/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1119 - accuracy: 0.9549 - val_loss: 0.3344 - val_accuracy: 0.9016
# Epoch 25/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0949 - accuracy: 0.9650 - val_loss: 0.3542 - val_accuracy: 0.9009
# Epoch 26/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1105 - accuracy: 0.9586 - val_loss: 0.4073 - val_accuracy: 0.8877
# Epoch 27/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0946 - accuracy: 0.9663 - val_loss: 0.3660 - val_accuracy: 0.8978
# Epoch 28/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0841 - accuracy: 0.9696 - val_loss: 0.3533 - val_accuracy: 0.9040
# Epoch 29/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0860 - accuracy: 0.9677 - val_loss: 0.3957 - val_accuracy: 0.8830
# Epoch 30/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0911 - accuracy: 0.9681 - val_loss: 0.3800 - val_accuracy: 0.9001
# Epoch 31/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0754 - accuracy: 0.9719 - val_loss: 0.3454 - val_accuracy: 0.8970
# Epoch 32/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0781 - accuracy: 0.9716 - val_loss: 0.3810 - val_accuracy: 0.8947
# Epoch 33/40
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0739 - accuracy: 0.9764 - val_loss: 0.4560 - val_accuracy: 0.8823
# Epoch 34/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0643 - accuracy: 0.9785 - val_loss: 0.3502 - val_accuracy: 0.9009
# Epoch 35/40
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0602 - accuracy: 0.9779 - val_loss: 0.3666 - val_accuracy: 0.8947
# Epoch 36/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0605 - accuracy: 0.9768 - val_loss: 0.3953 - val_accuracy: 0.9016
# Epoch 37/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0624 - accuracy: 0.9787 - val_loss: 0.3781 - val_accuracy: 0.9024
# Epoch 38/40
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0559 - accuracy: 0.9803 - val_loss: 0.3747 - val_accuracy: 0.8993
# Epoch 39/40
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0577 - accuracy: 0.9781 - val_loss: 0.4221 - val_accuracy: 0.9001
# Epoch 40/40
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0590 - accuracy: 0.9795 - val_loss: 0.3495 - val_accuracy: 0.8978

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_training(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3
# FOLD: 4
# FOLD: 5

# %%
test_batch_size = 32
validation_accuracies = []

for fold, model in enumerate(model_list):
    print(f'\nFOLD: {fold+1}')
    train_score = model.evaluate(train_data[fold], batch_size=test_batch_size, verbose= 1)
    valid_score = model.evaluate(val_data[fold], batch_size=test_batch_size, verbose= 1)

    print('-' * 20)
    print("Train Loss: ", train_score[0])
    print("Train Accuracy: ", train_score[1])
    print('-' * 20)
    print("Validation Loss: ", valid_score[0])
    print("Validation Accuracy: ", valid_score[1])
    print('-' * 20)

    validation_accuracies.append(valid_score[1])
    hours = duration_list[fold]['hours']
    minutes = duration_list[fold]['minutes']
    seconds = duration_list[fold]['seconds']

    msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
    print(msg)

best_fold = np.argmax(validation_accuracies)
best_model = model_list[best_fold]
print ("Best Fold berada pada : ",best_fold)
print (best_model)
# Out:
# FOLD: 1
# 162/162 [==============================] - 15s 92ms/step - loss: 0.0105 - accuracy: 0.9983
# 41/41 [==============================] - 4s 89ms/step - loss: 0.4073 - accuracy: 0.8932
# --------------------
# Train Loss:  0.010491685941815376
# Train Accuracy:  0.9982581734657288
# --------------------
# Validation Loss:  0.40730154514312744
# Validation Accuracy:  0.8931888341903687
# --------------------
# training elapsed time was 0.0 hours, 14.0 minutes, 39.94 seconds)
#
# FOLD: 2
# 162/162 [==============================] - 16s 94ms/step - loss: 0.0078 - accuracy: 0.9986
# 41/41 [==============================] - 3s 82ms/step - loss: 0.4317 - accuracy: 0.8862
# --------------------
# Train Loss:  0.007837945595383644
# Train Accuracy:  0.9986452460289001
# --------------------
# Validation Loss:  0.43169745802879333
# Validation Accuracy:  0.8862228989601135
# --------------------
# training elapsed time was 0.0 hours, 14.0 minutes, 40.27 seconds)
#
# FOLD: 3
# 162/162 [==============================] - 16s 94ms/step - loss: 0.0067 - accuracy: 0.9988
# 41/41 [==============================] - 4s 92ms/step - loss: 0.4466 - accuracy: 0.8793
# --------------------
# Train Loss:  0.006683786865323782
# Train Accuracy:  0.9988387823104858
# --------------------
# Validation Loss:  0.4466153085231781
# Validation Accuracy:  0.8792569637298584
# --------------------
# training elapsed time was 0.0 hours, 14.0 minutes, 41.36 seconds)
#
# FOLD: 4
# 162/162 [==============================] - 16s 95ms/step - loss: 0.0044 - accuracy: 0.9994
# 41/41 [==============================] - 4s 87ms/step - loss: 0.3450 - accuracy: 0.9094
# --------------------
# Train Loss:  0.004417465068399906
# Train Accuracy:  0.9994193911552429
# --------------------
# Validation Loss:  0.3449729382991791
# Validation Accuracy:  0.9094427227973938
# --------------------
# training elapsed time was 0.0 hours, 14.0 minutes, 42.85 seconds)
#
# FOLD: 5
# 162/162 [==============================] - 16s 95ms/step - loss: 0.0042 - accuracy: 0.9998
# 41/41 [==============================] - 4s 86ms/step - loss: 0.3495 - accuracy: 0.8978
# --------------------
# Train Loss:  0.004220006056129932
# Train Accuracy:  0.9998065233230591
# --------------------
# Validation Loss:  0.3495157063007355
# Validation Accuracy:  0.8977536559104919
# --------------------
# training elapsed time was 0.0 hours, 14.0 minutes, 42.59 seconds)
# Best Fold berada pada :  3
# <keras.src.engine.sequential.Sequential object at 0x79c77b6f6500>

# %%
preds = best_model.predict_generator(test_gen, verbose=1)
y_pred = np.argmax(preds, axis=1)
print(y_pred)
# Out:
# 51/51 [==============================] - 6s 90ms/step
# [0 0 1 ... 1 1 1]

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

cm = confusion_matrix(test_gen.classes, y_pred)
plot_confusion_matrix(cm= cm, classes= classes, title = 'Confusion Matrix')

    # Classification report
print(classification_report(test_gen.classes, y_pred, target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#          all       0.91      0.88      0.89       808
#          hem       0.88      0.91      0.90       807
#
#     accuracy                           0.90      1615
#    macro avg       0.90      0.90      0.90      1615
# weighted avg       0.90      0.90      0.90      1615

# %%
from sklearn import metrics


y_prob = []

for data in preds:
    y_prob.append(data[1])

fpr, tpr, thresholds = metrics.roc_curve(test_gen.classes, y_prob)
auc = metrics.auc(fpr, tpr)

plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], 'k--')  # Garis diagonal untuk klasifikasi acak
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()
