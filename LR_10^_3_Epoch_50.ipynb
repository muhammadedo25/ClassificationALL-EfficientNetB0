# %%
# import system libs
import glob
import os
import time
import shutil
import pathlib
import itertools

# import data handling tools
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import resample
from sklearn.model_selection import KFold

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.activations import relu
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
def undersample_dataframe(df, target_column):
    # Menghitung jumlah sampel untuk setiap kelas
    label_counts = df[target_column].value_counts()

    # Menentukan jumlah sampel terkecil pada kelas
    min_label_count = label_counts.min()

    # Inisialisasi dataframe kosong untuk menyimpan sampel undersampled
    undersampled_df = pd.DataFrame()

    # Melakukan undersampling pada setiap kelas
    for label in label_counts.index:
        # Memilih sampel acak dengan jumlah yang sesuai dari setiap kelas
        undersampled_class_df = resample(
            df[df[target_column] == label],
            replace=False,  # Tidak mengganti sampel yang dipilih
            n_samples=min_label_count,  # Jumlah sampel yang sesuai
            random_state=42  # Seed untuk reproduksi
        )

        # Menyimpan sampel undersampled
        undersampled_df = pd.concat([undersampled_df, undersampled_class_df])

    return undersampled_df

# %%
# Function that create dataframe for train, and test data
def create_df(df_fix):
    # train dataframe
    df = df_fix
    strat = df['labels']
    train_df, test_df = train_test_split(df, train_size=0.8, shuffle=True, random_state=42, stratify=strat)

    return train_df, test_df

# %%
def create_model_data_test (test_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR atau Grayscale
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    ts_length = len(test_df)
    test_batch_size = 32

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    ts_gen = ImageDataGenerator(preprocessing_function= scalar)

    test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= False, batch_size= test_batch_size)

    return test_gen

# %%
def create_model_data_train (train_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    tr_gen = ImageDataGenerator(preprocessing_function= scalar, horizontal_flip= True)

    train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    return train_gen

# %%
def create_model_data_valid (valid_df, batch_size):

    # define model parameters
    img_size = (224, 224)
    channels = 3 # channel BGR atau Grayscale
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    # Fungsi ini yang akan digunakan dalam generator data gambar untuk augmentasi data, hanya mengambil gambar dan mengembalikannya lagi
    def scalar(img):
        return img

    ts_gen = ImageDataGenerator(preprocessing_function= scalar)

    valid_gen = ts_gen.flow_from_dataframe( valid_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    return valid_gen

# %%
def show_images(gen):

    # mengembalikan kelas, gambar yang akan ditampilkan
    g_dict = gen.class_indices        # defines dictionary {'class': index}
    classes = list(g_dict.keys())     # mendefinisikan list dari dictionary keys (classes), classes names : string
    images, labels = next(gen)        # dapatkan ukuran batch size samples dari generator

    # menghitung banyaknya sample yang ditampilkan
    length = len(labels)        # panjang dari batch size
    sample = min(length, 25)    # cek jika sample kurang dari 25 gambar

    plt.figure(figsize= (20, 20))

    for i in range(sample):
        plt.subplot(5, 5, i + 1)
        image = images[i] / 255       # menskalakan data dalam rentang (0 - 255)
        plt.imshow(image)
        index = np.argmax(labels[i])  # dapatkan index gambar
        class_name = classes[index]   # dapatkan class dari gambar
        plt.title(class_name, color= 'blue', fontsize= 12)
        plt.axis('off')
    plt.show()

# %%
GCS_PATH = '/content/drive/MyDrive/Leukemia/'

# Membaca Data Train

train_dataset_0_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_0/all/*.bmp')
train_dataset_0_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_0/hem/*.bmp')
train_dataset_1_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_1/all/*.bmp')
train_dataset_1_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_1/hem/*.bmp')
train_dataset_2_all = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_2/all/*.bmp')
train_dataset_2_hem = glob.glob(GCS_PATH + 'C-NMC_Leukemia/training_data/fold_2/hem/*.bmp')

# Merging data:-
A=[]
H=[]

A.extend(train_dataset_0_all)
A.extend(train_dataset_1_all)
A.extend(train_dataset_2_all)

H.extend(train_dataset_0_hem)
H.extend(train_dataset_1_hem)
H.extend(train_dataset_2_hem)

print('Data Train')
print(len(A))
print(len(H))

# Membuat labels :-
Label_A = [1]*len(A)
Label_H = [0]*len(H)

# Convert ke pandas dataframe untuk memudahkan akses:-
A.extend(H)
Label_A.extend(Label_H)
df = pd.DataFrame({'filepaths':A, 'labels':Label_A})
df = df.sample(frac=1).reset_index(drop=True)

# Include Validation data
test_data=pd.read_csv(GCS_PATH + 'C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data_labels.csv')

at = test_data[test_data['labels'] == 1]
ht = test_data[test_data['labels'] == 0]

test_PATH = GCS_PATH + 'C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/'
ATL = [test_PATH +  i for i in list(at.new_names)]
HTL = [test_PATH +  i for i in list(ht.new_names)]

TA=[]
TH=[]

TA.extend(ATL)
TH.extend(HTL)

print('\nData Test')
print(len(TA))
print(len(TH))

# Membuat Tabel
Label_TA = [1]*len(TA)
Label_TH = [0]*len(TH)

# Convert ke Pandas DataFrame
TA.extend(TH)
Label_TA.extend(Label_TH)
tdf = pd.DataFrame({'filepaths':TA, 'labels':Label_TA})
tdf = tdf.sample(frac=1).reset_index(drop=True)
# Out:
# Data Train
# 7272
# 3389
#
# Data Test
# 1219
# 648

# %%
df_combined = pd.concat([df, tdf], ignore_index=True)
df_combined['labels'] = df_combined['labels'].replace({1: 'all', 0: 'hem'})
df_combined
# Out:
#                                                filepaths labels
# 0      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 1      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 2      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 3      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 4      /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# ...                                                  ...    ...
# 12523  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 12524  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 12525  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 12526  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 12527  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
#
# [12528 rows x 2 columns]

# %%
df_fix = undersample_dataframe(df_combined, 'labels')
df_fix = df_fix.reset_index(drop=True)
df_fix
# Out:
#                                               filepaths labels
# 0     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 1     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 2     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 3     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# 4     /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    all
# ...                                                 ...    ...
# 8069  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8070  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8071  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8072  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
# 8073  /content/drive/MyDrive/Leukemia/C-NMC_Leukemia...    hem
#
# [8074 rows x 2 columns]

# %%
print("Total number of images in the dataset: ", len(df_fix))

label_count = df_fix['labels'].value_counts()
print(label_count)
# Out:
# Total number of images in the dataset:  8074
# all    4037
# hem    4037
# Name: labels, dtype: int64

# %%
# Get splitted data
train_df, test_df = create_df(df_fix)

# Get Generators
batch_size = 32
test_gen = create_model_data_test(test_df, batch_size)
# Out:
# Found 1615 validated image filenames belonging to 2 classes.

# %%
show_images(test_gen)

# %%
def plot_training(hist):
    '''
    Function ini mengambil model pelatihan dan riwayat plot akurasi dan loss dengan epoch terbaik di keduanya.
    '''

    # Define variables yang dibutuhkan
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training dan Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training dan Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
def plot_confusion_matrix(cm, classes, title= 'Confusion Matrix', cmap= plt.cm.Blues):
    '''
    Function ini digunakan untuk memplot confusion matrix menggunakan sklearn package.
    '''

    plt.figure(figsize= (10, 10))
    plt.imshow(cm, interpolation= 'nearest', cmap= cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation= 45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')

# %%
def efficientNet_B0():
    # Create Model Structure
    img_size = (224, 224)
    channels = 3
    img_shape = (img_size[0], img_size[1], channels)

    base_model = tf.keras.applications.efficientnet.EfficientNetB0(include_top= False, weights= 'imagenet', input_shape= img_shape, pooling= 'max')

    model = Sequential([
        base_model,
        BatchNormalization(),
        Dense(256, activation=relu),
        Dropout(0.2),
        Dense(2, activation='sigmoid')
    ])
    model.compile(Adamax(learning_rate= 0.001), loss= 'binary_crossentropy', metrics= ['accuracy'])

    return model

# %%
history_list, model_list = [], []
train_data, val_data  = [], []
duration_list = []
kfold=5
epochs=50
fold = 1

kf = KFold(n_splits=kfold, shuffle=True, random_state=42)
fold_indices = kf.split(train_df)

for fold, (train_index, val_index) in enumerate(fold_indices):
    print(f'\nFOLD: {fold+1}')

    # Inisialisasi DataFrame baru untuk menyimpan data pelatihan dan validation
    train_subset_df = pd.DataFrame()
    valid_subset_df = pd.DataFrame()

    fold_train_df = train_df.iloc[train_index] # Bagi data menjadi set pelatihan dan validasi
    fold_valid_df = train_df.iloc[val_index]

    # Tambahkan data pelatihan dan validation pada lipatan ini ke DataFrame baru
    train_subset_df = pd.concat([train_subset_df, fold_train_df], ignore_index=True)
    valid_subset_df = pd.concat([valid_subset_df, fold_valid_df], ignore_index=True)

    train_gen = create_model_data_train(train_subset_df, batch_size) # generate data train dan valid
    valid_gen = create_model_data_valid(valid_subset_df, batch_size)

    K.clear_session()
    print('\nMODEL SUMMARY:')
    model = efficientNet_B0()
    model.summary()

    print('\nFITTING MODEL:')
    start_time = time.time() # mencatat waktu mulai
    history = model.fit(x= train_gen, epochs= epochs, verbose= 1,
                    validation_data= valid_gen, validation_steps= None, shuffle= False)


    stop_time = time.time()
    tr_duration = stop_time - start_time
    hours = tr_duration // 3600
    minutes = (tr_duration - (hours * 3600)) // 60
    seconds = tr_duration - ((hours * 3600) + (minutes * 60))
    sum_duration = {
        'hours' : hours,
        'minutes' : minutes,
        'seconds' : seconds
    }

    duration_list.append(sum_duration)

    history_list.append(history)
    model_list.append(model)

    train_data.append(train_gen)
    val_data.append(valid_gen)
# Out:
# FOLD: 1
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/50
# 162/162 [==============================] - 49s 141ms/step - loss: 0.6398 - accuracy: 0.7376 - val_loss: 0.7047 - val_accuracy: 0.6858
# Epoch 2/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3805 - accuracy: 0.8370 - val_loss: 0.5223 - val_accuracy: 0.7663
# Epoch 3/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3020 - accuracy: 0.8744 - val_loss: 0.3401 - val_accuracy: 0.8522
# Epoch 4/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2611 - accuracy: 0.8928 - val_loss: 0.3645 - val_accuracy: 0.8529
# Epoch 5/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2178 - accuracy: 0.9069 - val_loss: 0.3663 - val_accuracy: 0.8522
# Epoch 6/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1834 - accuracy: 0.9237 - val_loss: 0.2741 - val_accuracy: 0.8963
# Epoch 7/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1708 - accuracy: 0.9325 - val_loss: 0.3257 - val_accuracy: 0.8684
# Epoch 8/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1358 - accuracy: 0.9468 - val_loss: 1.2714 - val_accuracy: 0.7268
# Epoch 9/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1253 - accuracy: 0.9532 - val_loss: 0.2887 - val_accuracy: 0.9040
# Epoch 10/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1178 - accuracy: 0.9559 - val_loss: 0.3725 - val_accuracy: 0.8777
# Epoch 11/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0951 - accuracy: 0.9638 - val_loss: 0.3545 - val_accuracy: 0.8924
# Epoch 12/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0891 - accuracy: 0.9675 - val_loss: 0.2901 - val_accuracy: 0.8994
# Epoch 13/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0848 - accuracy: 0.9673 - val_loss: 0.3414 - val_accuracy: 0.9211
# Epoch 14/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0620 - accuracy: 0.9770 - val_loss: 0.3508 - val_accuracy: 0.8824
# Epoch 15/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0719 - accuracy: 0.9735 - val_loss: 0.6198 - val_accuracy: 0.8715
# Epoch 16/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0566 - accuracy: 0.9799 - val_loss: 0.3291 - val_accuracy: 0.9063
# Epoch 17/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0483 - accuracy: 0.9814 - val_loss: 0.3723 - val_accuracy: 0.8963
# Epoch 18/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0459 - accuracy: 0.9837 - val_loss: 0.8609 - val_accuracy: 0.8514
# Epoch 19/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0376 - accuracy: 0.9868 - val_loss: 0.2720 - val_accuracy: 0.9164
# Epoch 20/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0413 - accuracy: 0.9832 - val_loss: 0.7103 - val_accuracy: 0.8568
# Epoch 21/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0442 - accuracy: 0.9849 - val_loss: 0.4694 - val_accuracy: 0.8847
# Epoch 22/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0322 - accuracy: 0.9890 - val_loss: 0.4039 - val_accuracy: 0.9025
# Epoch 23/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0345 - accuracy: 0.9884 - val_loss: 0.2859 - val_accuracy: 0.9180
# Epoch 24/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0322 - accuracy: 0.9888 - val_loss: 0.5892 - val_accuracy: 0.9156
# Epoch 25/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0434 - accuracy: 0.9847 - val_loss: 0.9947 - val_accuracy: 0.8127
# Epoch 26/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0290 - accuracy: 0.9884 - val_loss: 0.3168 - val_accuracy: 0.9164
# Epoch 27/50
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0306 - accuracy: 0.9892 - val_loss: 0.5280 - val_accuracy: 0.9056
# Epoch 28/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0290 - accuracy: 0.9913 - val_loss: 0.5958 - val_accuracy: 0.8800
# Epoch 29/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.3904 - val_accuracy: 0.9234
# Epoch 30/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0317 - accuracy: 0.9894 - val_loss: 0.3120 - val_accuracy: 0.9110
# Epoch 31/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 0.3307 - val_accuracy: 0.9234
# Epoch 32/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0145 - accuracy: 0.9944 - val_loss: 0.6948 - val_accuracy: 0.8754
# Epoch 33/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0173 - accuracy: 0.9942 - val_loss: 0.6023 - val_accuracy: 0.9040
# Epoch 34/50
# 162/162 [==============================] - 22s 136ms/step - loss: 0.0222 - accuracy: 0.9932 - val_loss: 0.4267 - val_accuracy: 0.9094
# Epoch 35/50
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0160 - accuracy: 0.9936 - val_loss: 0.4412 - val_accuracy: 0.9087
# Epoch 36/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0236 - accuracy: 0.9923 - val_loss: 0.5407 - val_accuracy: 0.8816
# Epoch 37/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0244 - accuracy: 0.9921 - val_loss: 0.5860 - val_accuracy: 0.8785
# Epoch 38/50
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0179 - accuracy: 0.9950 - val_loss: 0.3605 - val_accuracy: 0.9288
# Epoch 39/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0185 - accuracy: 0.9944 - val_loss: 0.5660 - val_accuracy: 0.8963
# Epoch 40/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0147 - accuracy: 0.9952 - val_loss: 0.5044 - val_accuracy: 0.9118
# Epoch 41/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0280 - accuracy: 0.9903 - val_loss: 0.3298 - val_accuracy: 0.9280
# Epoch 42/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0134 - accuracy: 0.9959 - val_loss: 0.4411 - val_accuracy: 0.9327
# Epoch 43/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0165 - accuracy: 0.9932 - val_loss: 0.4557 - val_accuracy: 0.9094
# Epoch 44/50
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0184 - accuracy: 0.9930 - val_loss: 0.4749 - val_accuracy: 0.9226
# Epoch 45/50
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0166 - accuracy: 0.9942 - val_loss: 0.3857 - val_accuracy: 0.9141
# Epoch 46/50
# 162/162 [==============================] - 25s 153ms/step - loss: 0.0126 - accuracy: 0.9963 - val_loss: 0.4205 - val_accuracy: 0.9079
# Epoch 47/50
# 162/162 [==============================] - 26s 157ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.3799 - val_accuracy: 0.9265
# Epoch 48/50
# 162/162 [==============================] - 24s 150ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.3962 - val_accuracy: 0.9195
# Epoch 49/50
# 162/162 [==============================] - 22s 135ms/step - loss: 0.0119 - accuracy: 0.9957 - val_loss: 0.4886 - val_accuracy: 0.9102
# Epoch 50/50
# 162/162 [==============================] - 22s 135ms/step - loss: 0.0212 - accuracy: 0.9938 - val_loss: 0.3679 - val_accuracy: 0.9079
#
# FOLD: 2
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/50
# 162/162 [==============================] - 56s 167ms/step - loss: 0.6496 - accuracy: 0.7312 - val_loss: 1.0556 - val_accuracy: 0.5906
# Epoch 2/50
# 162/162 [==============================] - 24s 148ms/step - loss: 0.4501 - accuracy: 0.8090 - val_loss: 2.9349 - val_accuracy: 0.5372
# Epoch 3/50
# 162/162 [==============================] - 24s 145ms/step - loss: 0.3512 - accuracy: 0.8518 - val_loss: 0.3798 - val_accuracy: 0.8220
# Epoch 4/50
# 162/162 [==============================] - 22s 135ms/step - loss: 0.2761 - accuracy: 0.8804 - val_loss: 0.3916 - val_accuracy: 0.8537
# Epoch 5/50
# 162/162 [==============================] - 22s 134ms/step - loss: 0.2243 - accuracy: 0.9085 - val_loss: 0.3713 - val_accuracy: 0.8375
# Epoch 6/50
# 162/162 [==============================] - 22s 134ms/step - loss: 0.1882 - accuracy: 0.9253 - val_loss: 0.3178 - val_accuracy: 0.8498
# Epoch 7/50
# 162/162 [==============================] - 23s 141ms/step - loss: 0.1543 - accuracy: 0.9373 - val_loss: 0.3620 - val_accuracy: 0.8692
# Epoch 8/50
# 162/162 [==============================] - 25s 153ms/step - loss: 0.1454 - accuracy: 0.9417 - val_loss: 0.3131 - val_accuracy: 0.8692
# Epoch 9/50
# 162/162 [==============================] - 26s 160ms/step - loss: 0.1249 - accuracy: 0.9543 - val_loss: 0.4066 - val_accuracy: 0.8367
# Epoch 10/50
# 162/162 [==============================] - 22s 134ms/step - loss: 0.1070 - accuracy: 0.9584 - val_loss: 0.3468 - val_accuracy: 0.8847
# Epoch 11/50
# 162/162 [==============================] - 22s 134ms/step - loss: 0.1074 - accuracy: 0.9576 - val_loss: 0.3163 - val_accuracy: 0.8885
# Epoch 12/50
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0878 - accuracy: 0.9686 - val_loss: 0.4357 - val_accuracy: 0.8676
# Epoch 13/50
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0657 - accuracy: 0.9768 - val_loss: 0.5070 - val_accuracy: 0.8498
# Epoch 14/50
# 162/162 [==============================] - 25s 155ms/step - loss: 0.0804 - accuracy: 0.9700 - val_loss: 1.2942 - val_accuracy: 0.7198
# Epoch 15/50
# 162/162 [==============================] - 25s 155ms/step - loss: 0.0520 - accuracy: 0.9818 - val_loss: 0.3282 - val_accuracy: 0.9033
# Epoch 16/50
# 162/162 [==============================] - 23s 140ms/step - loss: 0.0511 - accuracy: 0.9808 - val_loss: 0.3704 - val_accuracy: 0.8777
# Epoch 17/50
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0600 - accuracy: 0.9808 - val_loss: 0.3531 - val_accuracy: 0.8553
# Epoch 18/50
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0439 - accuracy: 0.9855 - val_loss: 0.2656 - val_accuracy: 0.9218
# Epoch 19/50
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0434 - accuracy: 0.9835 - val_loss: 0.4648 - val_accuracy: 0.8839
# Epoch 20/50
# 162/162 [==============================] - 23s 144ms/step - loss: 0.0374 - accuracy: 0.9859 - val_loss: 0.2647 - val_accuracy: 0.9272
# Epoch 21/50
# 162/162 [==============================] - 25s 154ms/step - loss: 0.0325 - accuracy: 0.9894 - val_loss: 0.4222 - val_accuracy: 0.9063
# Epoch 22/50
# 162/162 [==============================] - 24s 147ms/step - loss: 0.0360 - accuracy: 0.9866 - val_loss: 0.3688 - val_accuracy: 0.9203
# Epoch 23/50
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0362 - accuracy: 0.9868 - val_loss: 0.3042 - val_accuracy: 0.9056
# Epoch 24/50
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0334 - accuracy: 0.9884 - val_loss: 0.6277 - val_accuracy: 0.8638
# Epoch 25/50
# 162/162 [==============================] - 22s 134ms/step - loss: 0.0310 - accuracy: 0.9882 - val_loss: 0.3798 - val_accuracy: 0.9033
# Epoch 26/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0301 - accuracy: 0.9905 - val_loss: 0.3910 - val_accuracy: 0.9187
# Epoch 27/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0277 - accuracy: 0.9903 - val_loss: 0.3058 - val_accuracy: 0.9110
# Epoch 28/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0237 - accuracy: 0.9911 - val_loss: 0.3560 - val_accuracy: 0.9241
# Epoch 29/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0256 - accuracy: 0.9913 - val_loss: 0.3740 - val_accuracy: 0.9164
# Epoch 30/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0246 - accuracy: 0.9919 - val_loss: 0.5996 - val_accuracy: 0.8978
# Epoch 31/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0149 - accuracy: 0.9942 - val_loss: 0.5752 - val_accuracy: 0.8854
# Epoch 32/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0161 - accuracy: 0.9938 - val_loss: 0.5823 - val_accuracy: 0.8793
# Epoch 33/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0226 - accuracy: 0.9919 - val_loss: 0.5832 - val_accuracy: 0.9079
# Epoch 34/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0244 - accuracy: 0.9903 - val_loss: 0.4769 - val_accuracy: 0.8746
# Epoch 35/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0185 - accuracy: 0.9928 - val_loss: 0.4937 - val_accuracy: 0.9172
# Epoch 36/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0265 - accuracy: 0.9917 - val_loss: 0.3631 - val_accuracy: 0.9040
# Epoch 37/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0199 - accuracy: 0.9942 - val_loss: 0.3846 - val_accuracy: 0.9241
# Epoch 38/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0170 - accuracy: 0.9938 - val_loss: 0.3285 - val_accuracy: 0.9218
# Epoch 39/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0133 - accuracy: 0.9959 - val_loss: 0.4316 - val_accuracy: 0.9118
# Epoch 40/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.8333 - val_accuracy: 0.8584
# Epoch 41/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0218 - accuracy: 0.9936 - val_loss: 0.3689 - val_accuracy: 0.9087
# Epoch 42/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0191 - accuracy: 0.9946 - val_loss: 0.4145 - val_accuracy: 0.9218
# Epoch 43/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.4375 - val_accuracy: 0.9180
# Epoch 44/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.3886 - val_accuracy: 0.9296
# Epoch 45/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0119 - accuracy: 0.9954 - val_loss: 0.3069 - val_accuracy: 0.9164
# Epoch 46/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.5053 - val_accuracy: 0.9133
# Epoch 47/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0136 - accuracy: 0.9948 - val_loss: 0.5774 - val_accuracy: 0.9009
# Epoch 48/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0131 - accuracy: 0.9948 - val_loss: 0.5330 - val_accuracy: 0.9149
# Epoch 49/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.3891 - val_accuracy: 0.9272
# Epoch 50/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0102 - accuracy: 0.9961 - val_loss: 0.3270 - val_accuracy: 0.9420
#
# FOLD: 3
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/50
# 162/162 [==============================] - 48s 140ms/step - loss: 0.6350 - accuracy: 0.7304 - val_loss: 1.2699 - val_accuracy: 0.5573
# Epoch 2/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3842 - accuracy: 0.8343 - val_loss: 0.7254 - val_accuracy: 0.6827
# Epoch 3/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2978 - accuracy: 0.8783 - val_loss: 0.2903 - val_accuracy: 0.8746
# Epoch 4/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2423 - accuracy: 0.9009 - val_loss: 0.3475 - val_accuracy: 0.8483
# Epoch 5/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2201 - accuracy: 0.9108 - val_loss: 0.2850 - val_accuracy: 0.8746
# Epoch 6/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1982 - accuracy: 0.9201 - val_loss: 0.3157 - val_accuracy: 0.8444
# Epoch 7/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1610 - accuracy: 0.9373 - val_loss: 0.3554 - val_accuracy: 0.8390
# Epoch 8/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.1421 - accuracy: 0.9445 - val_loss: 0.3679 - val_accuracy: 0.8359
# Epoch 9/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1309 - accuracy: 0.9476 - val_loss: 0.2839 - val_accuracy: 0.8862
# Epoch 10/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1163 - accuracy: 0.9541 - val_loss: 0.3313 - val_accuracy: 0.8831
# Epoch 11/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0952 - accuracy: 0.9650 - val_loss: 0.4890 - val_accuracy: 0.8266
# Epoch 12/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0887 - accuracy: 0.9671 - val_loss: 0.4194 - val_accuracy: 0.8607
# Epoch 13/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0790 - accuracy: 0.9688 - val_loss: 0.2577 - val_accuracy: 0.9110
# Epoch 14/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0722 - accuracy: 0.9717 - val_loss: 0.3027 - val_accuracy: 0.8785
# Epoch 15/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0613 - accuracy: 0.9775 - val_loss: 0.5559 - val_accuracy: 0.8367
# Epoch 16/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0693 - accuracy: 0.9764 - val_loss: 0.3679 - val_accuracy: 0.8599
# Epoch 17/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0511 - accuracy: 0.9808 - val_loss: 0.2974 - val_accuracy: 0.9164
# Epoch 18/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0483 - accuracy: 0.9834 - val_loss: 0.2705 - val_accuracy: 0.9249
# Epoch 19/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0505 - accuracy: 0.9816 - val_loss: 0.4139 - val_accuracy: 0.8916
# Epoch 20/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0380 - accuracy: 0.9882 - val_loss: 0.3065 - val_accuracy: 0.9172
# Epoch 21/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0461 - accuracy: 0.9830 - val_loss: 0.2800 - val_accuracy: 0.9203
# Epoch 22/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0365 - accuracy: 0.9878 - val_loss: 0.3248 - val_accuracy: 0.9187
# Epoch 23/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0413 - accuracy: 0.9845 - val_loss: 0.3767 - val_accuracy: 0.8878
# Epoch 24/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0312 - accuracy: 0.9888 - val_loss: 0.4556 - val_accuracy: 0.8885
# Epoch 25/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0288 - accuracy: 0.9895 - val_loss: 0.3132 - val_accuracy: 0.9156
# Epoch 26/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0369 - accuracy: 0.9876 - val_loss: 0.3748 - val_accuracy: 0.8878
# Epoch 27/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0244 - accuracy: 0.9917 - val_loss: 0.4830 - val_accuracy: 0.8808
# Epoch 28/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0261 - accuracy: 0.9911 - val_loss: 0.3623 - val_accuracy: 0.9056
# Epoch 29/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0227 - accuracy: 0.9917 - val_loss: 0.4132 - val_accuracy: 0.9002
# Epoch 30/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0224 - accuracy: 0.9928 - val_loss: 0.3804 - val_accuracy: 0.9009
# Epoch 31/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0251 - accuracy: 0.9921 - val_loss: 0.3706 - val_accuracy: 0.9040
# Epoch 32/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0216 - accuracy: 0.9925 - val_loss: 0.4720 - val_accuracy: 0.8777
# Epoch 33/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0178 - accuracy: 0.9934 - val_loss: 0.4122 - val_accuracy: 0.9164
# Epoch 34/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0223 - accuracy: 0.9919 - val_loss: 0.2857 - val_accuracy: 0.9187
# Epoch 35/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0214 - accuracy: 0.9934 - val_loss: 0.3686 - val_accuracy: 0.9048
# Epoch 36/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0135 - accuracy: 0.9963 - val_loss: 0.4575 - val_accuracy: 0.9180
# Epoch 37/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0209 - accuracy: 0.9944 - val_loss: 0.4663 - val_accuracy: 0.8762
# Epoch 38/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0284 - accuracy: 0.9921 - val_loss: 0.2889 - val_accuracy: 0.9211
# Epoch 39/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.4481 - val_accuracy: 0.9002
# Epoch 40/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0167 - accuracy: 0.9946 - val_loss: 0.2951 - val_accuracy: 0.9218
# Epoch 41/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0199 - accuracy: 0.9928 - val_loss: 0.5382 - val_accuracy: 0.8909
# Epoch 42/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0116 - accuracy: 0.9957 - val_loss: 0.3424 - val_accuracy: 0.9133
# Epoch 43/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0191 - accuracy: 0.9932 - val_loss: 0.4334 - val_accuracy: 0.8847
# Epoch 44/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 0.4004 - val_accuracy: 0.9133
# Epoch 45/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0063 - accuracy: 0.9973 - val_loss: 0.4575 - val_accuracy: 0.9102
# Epoch 46/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0177 - accuracy: 0.9930 - val_loss: 0.7423 - val_accuracy: 0.8824
# Epoch 47/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.3219 - val_accuracy: 0.9303
# Epoch 48/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0198 - accuracy: 0.9926 - val_loss: 0.3146 - val_accuracy: 0.9327
# Epoch 49/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.3627 - val_accuracy: 0.9203
# Epoch 50/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.9519 - val_accuracy: 0.8135
#
# FOLD: 4
# Found 5167 validated image filenames belonging to 2 classes.
# Found 1292 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/50
# 162/162 [==============================] - 50s 143ms/step - loss: 0.5962 - accuracy: 0.7414 - val_loss: 0.4762 - val_accuracy: 0.7663
# Epoch 2/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3946 - accuracy: 0.8233 - val_loss: 0.8794 - val_accuracy: 0.6455
# Epoch 3/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.3154 - accuracy: 0.8665 - val_loss: 0.3266 - val_accuracy: 0.8537
# Epoch 4/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2714 - accuracy: 0.8883 - val_loss: 0.5116 - val_accuracy: 0.7779
# Epoch 5/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2350 - accuracy: 0.9056 - val_loss: 0.2726 - val_accuracy: 0.8870
# Epoch 6/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2065 - accuracy: 0.9160 - val_loss: 0.3255 - val_accuracy: 0.8669
# Epoch 7/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1720 - accuracy: 0.9319 - val_loss: 0.2685 - val_accuracy: 0.8932
# Epoch 8/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1576 - accuracy: 0.9392 - val_loss: 0.3287 - val_accuracy: 0.8731
# Epoch 9/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1428 - accuracy: 0.9423 - val_loss: 0.6267 - val_accuracy: 0.8003
# Epoch 10/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1232 - accuracy: 0.9534 - val_loss: 0.8973 - val_accuracy: 0.7531
# Epoch 11/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0932 - accuracy: 0.9656 - val_loss: 0.3157 - val_accuracy: 0.8947
# Epoch 12/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0879 - accuracy: 0.9648 - val_loss: 0.3432 - val_accuracy: 0.8854
# Epoch 13/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0792 - accuracy: 0.9690 - val_loss: 0.5220 - val_accuracy: 0.8390
# Epoch 14/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0634 - accuracy: 0.9750 - val_loss: 0.3271 - val_accuracy: 0.9071
# Epoch 15/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0754 - accuracy: 0.9712 - val_loss: 0.3992 - val_accuracy: 0.9002
# Epoch 16/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0560 - accuracy: 0.9820 - val_loss: 0.4858 - val_accuracy: 0.8870
# Epoch 17/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0538 - accuracy: 0.9779 - val_loss: 0.3505 - val_accuracy: 0.9094
# Epoch 18/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0376 - accuracy: 0.9868 - val_loss: 0.3064 - val_accuracy: 0.9110
# Epoch 19/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0506 - accuracy: 0.9806 - val_loss: 0.2831 - val_accuracy: 0.9133
# Epoch 20/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0383 - accuracy: 0.9849 - val_loss: 0.3747 - val_accuracy: 0.9203
# Epoch 21/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0380 - accuracy: 0.9868 - val_loss: 0.3743 - val_accuracy: 0.9141
# Epoch 22/50
# 162/162 [==============================] - 22s 133ms/step - loss: 0.0426 - accuracy: 0.9851 - val_loss: 0.2764 - val_accuracy: 0.9319
# Epoch 23/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0408 - accuracy: 0.9865 - val_loss: 0.4548 - val_accuracy: 0.9071
# Epoch 24/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0353 - accuracy: 0.9868 - val_loss: 0.2957 - val_accuracy: 0.9373
# Epoch 25/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0316 - accuracy: 0.9872 - val_loss: 1.0721 - val_accuracy: 0.7307
# Epoch 26/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0240 - accuracy: 0.9901 - val_loss: 0.3532 - val_accuracy: 0.9272
# Epoch 27/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0314 - accuracy: 0.9876 - val_loss: 0.4367 - val_accuracy: 0.9025
# Epoch 28/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0271 - accuracy: 0.9909 - val_loss: 0.2993 - val_accuracy: 0.9249
# Epoch 29/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0221 - accuracy: 0.9923 - val_loss: 0.2702 - val_accuracy: 0.9195
# Epoch 30/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0247 - accuracy: 0.9919 - val_loss: 0.3305 - val_accuracy: 0.9319
# Epoch 31/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0253 - accuracy: 0.9923 - val_loss: 0.3319 - val_accuracy: 0.9296
# Epoch 32/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0236 - accuracy: 0.9921 - val_loss: 0.5142 - val_accuracy: 0.9025
# Epoch 33/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0191 - accuracy: 0.9934 - val_loss: 0.3599 - val_accuracy: 0.9311
# Epoch 34/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0216 - accuracy: 0.9932 - val_loss: 0.3529 - val_accuracy: 0.9311
# Epoch 35/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0201 - accuracy: 0.9928 - val_loss: 0.3171 - val_accuracy: 0.9218
# Epoch 36/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0157 - accuracy: 0.9948 - val_loss: 0.3825 - val_accuracy: 0.9056
# Epoch 37/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0147 - accuracy: 0.9942 - val_loss: 0.4939 - val_accuracy: 0.9180
# Epoch 38/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0178 - accuracy: 0.9932 - val_loss: 0.3523 - val_accuracy: 0.9303
# Epoch 39/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0202 - accuracy: 0.9926 - val_loss: 0.2427 - val_accuracy: 0.9350
# Epoch 40/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0130 - accuracy: 0.9965 - val_loss: 0.3647 - val_accuracy: 0.9342
# Epoch 41/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0195 - accuracy: 0.9932 - val_loss: 0.3639 - val_accuracy: 0.9234
# Epoch 42/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0242 - accuracy: 0.9907 - val_loss: 0.3477 - val_accuracy: 0.9234
# Epoch 43/50
# 162/162 [==============================] - 22s 132ms/step - loss: 0.0218 - accuracy: 0.9934 - val_loss: 0.2868 - val_accuracy: 0.9327
# Epoch 44/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.3922 - val_accuracy: 0.9272
# Epoch 45/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0163 - accuracy: 0.9942 - val_loss: 0.3637 - val_accuracy: 0.9149
# Epoch 46/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0184 - accuracy: 0.9946 - val_loss: 0.2819 - val_accuracy: 0.9365
# Epoch 47/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0117 - accuracy: 0.9959 - val_loss: 0.5475 - val_accuracy: 0.9071
# Epoch 48/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0159 - accuracy: 0.9938 - val_loss: 0.5313 - val_accuracy: 0.8932
# Epoch 49/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0120 - accuracy: 0.9952 - val_loss: 0.3180 - val_accuracy: 0.9373
# Epoch 50/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0132 - accuracy: 0.9955 - val_loss: 0.6417 - val_accuracy: 0.8831
#
# FOLD: 5
# Found 5168 validated image filenames belonging to 2 classes.
# Found 1291 validated image filenames belonging to 2 classes.
#
# MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________
#
# FITTING MODEL:
# Epoch 1/50
# 162/162 [==============================] - 50s 143ms/step - loss: 0.5927 - accuracy: 0.7467 - val_loss: 0.6124 - val_accuracy: 0.6677
# Epoch 2/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.3842 - accuracy: 0.8245 - val_loss: 0.4421 - val_accuracy: 0.8048
# Epoch 3/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.3105 - accuracy: 0.8640 - val_loss: 0.3156 - val_accuracy: 0.8629
# Epoch 4/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.2381 - accuracy: 0.9011 - val_loss: 0.3580 - val_accuracy: 0.8528
# Epoch 5/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.2086 - accuracy: 0.9160 - val_loss: 0.5951 - val_accuracy: 0.7885
# Epoch 6/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.2002 - accuracy: 0.9185 - val_loss: 0.2778 - val_accuracy: 0.8799
# Epoch 7/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.1554 - accuracy: 0.9371 - val_loss: 0.2882 - val_accuracy: 0.8815
# Epoch 8/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1574 - accuracy: 0.9375 - val_loss: 0.5957 - val_accuracy: 0.8079
# Epoch 9/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1333 - accuracy: 0.9509 - val_loss: 0.2835 - val_accuracy: 0.9047
# Epoch 10/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.1084 - accuracy: 0.9572 - val_loss: 0.2789 - val_accuracy: 0.9001
# Epoch 11/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.1048 - accuracy: 0.9603 - val_loss: 0.2713 - val_accuracy: 0.9078
# Epoch 12/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0907 - accuracy: 0.9652 - val_loss: 0.6261 - val_accuracy: 0.8164
# Epoch 13/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0801 - accuracy: 0.9688 - val_loss: 0.8740 - val_accuracy: 0.7746
# Epoch 14/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0731 - accuracy: 0.9752 - val_loss: 0.2327 - val_accuracy: 0.9125
# Epoch 15/50
# 162/162 [==============================] - 21s 132ms/step - loss: 0.0729 - accuracy: 0.9723 - val_loss: 0.2797 - val_accuracy: 0.9218
# Epoch 16/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0564 - accuracy: 0.9797 - val_loss: 0.2704 - val_accuracy: 0.9132
# Epoch 17/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0565 - accuracy: 0.9795 - val_loss: 0.3291 - val_accuracy: 0.9078
# Epoch 18/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0479 - accuracy: 0.9824 - val_loss: 0.4182 - val_accuracy: 0.8792
# Epoch 19/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0458 - accuracy: 0.9849 - val_loss: 0.3447 - val_accuracy: 0.8923
# Epoch 20/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0419 - accuracy: 0.9845 - val_loss: 0.7827 - val_accuracy: 0.8637
# Epoch 21/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0373 - accuracy: 0.9868 - val_loss: 0.3215 - val_accuracy: 0.9210
# Epoch 22/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0338 - accuracy: 0.9853 - val_loss: 0.5341 - val_accuracy: 0.8962
# Epoch 23/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0404 - accuracy: 0.9843 - val_loss: 0.3065 - val_accuracy: 0.9132
# Epoch 24/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0355 - accuracy: 0.9863 - val_loss: 0.2970 - val_accuracy: 0.9163
# Epoch 25/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0349 - accuracy: 0.9886 - val_loss: 0.3599 - val_accuracy: 0.9109
# Epoch 26/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0242 - accuracy: 0.9917 - val_loss: 0.3490 - val_accuracy: 0.9357
# Epoch 27/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0261 - accuracy: 0.9913 - val_loss: 0.3031 - val_accuracy: 0.9373
# Epoch 28/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0289 - accuracy: 0.9901 - val_loss: 0.3293 - val_accuracy: 0.9264
# Epoch 29/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0267 - accuracy: 0.9911 - val_loss: 0.3500 - val_accuracy: 0.9210
# Epoch 30/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0304 - accuracy: 0.9901 - val_loss: 0.2577 - val_accuracy: 0.9419
# Epoch 31/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0201 - accuracy: 0.9938 - val_loss: 0.5150 - val_accuracy: 0.8954
# Epoch 32/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0200 - accuracy: 0.9928 - val_loss: 0.4974 - val_accuracy: 0.9132
# Epoch 33/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0171 - accuracy: 0.9955 - val_loss: 0.3828 - val_accuracy: 0.9094
# Epoch 34/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0196 - accuracy: 0.9923 - val_loss: 0.3206 - val_accuracy: 0.9287
# Epoch 35/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0274 - accuracy: 0.9915 - val_loss: 0.7548 - val_accuracy: 0.8675
# Epoch 36/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0192 - accuracy: 0.9923 - val_loss: 0.5684 - val_accuracy: 0.8745
# Epoch 37/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0258 - accuracy: 0.9897 - val_loss: 0.4306 - val_accuracy: 0.9078
# Epoch 38/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0237 - accuracy: 0.9911 - val_loss: 0.2884 - val_accuracy: 0.9326
# Epoch 39/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.3134 - val_accuracy: 0.9264
# Epoch 40/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0227 - accuracy: 0.9936 - val_loss: 0.3351 - val_accuracy: 0.9249
# Epoch 41/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0230 - accuracy: 0.9932 - val_loss: 0.3622 - val_accuracy: 0.9117
# Epoch 42/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.5469 - val_accuracy: 0.9125
# Epoch 43/50
# 162/162 [==============================] - 21s 128ms/step - loss: 0.0233 - accuracy: 0.9928 - val_loss: 0.3447 - val_accuracy: 0.9001
# Epoch 44/50
# 162/162 [==============================] - 21s 131ms/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 0.3167 - val_accuracy: 0.9241
# Epoch 45/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0153 - accuracy: 0.9944 - val_loss: 0.4146 - val_accuracy: 0.9202
# Epoch 46/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 0.5250 - val_accuracy: 0.9117
# Epoch 47/50
# 162/162 [==============================] - 21s 130ms/step - loss: 0.0134 - accuracy: 0.9967 - val_loss: 0.3599 - val_accuracy: 0.9303
# Epoch 48/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0141 - accuracy: 0.9961 - val_loss: 0.3269 - val_accuracy: 0.9311
# Epoch 49/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0161 - accuracy: 0.9942 - val_loss: 0.2766 - val_accuracy: 0.9404
# Epoch 50/50
# 162/162 [==============================] - 21s 129ms/step - loss: 0.0090 - accuracy: 0.9963 - val_loss: 0.3559 - val_accuracy: 0.9311

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_training(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3
# FOLD: 4
# FOLD: 5

# %%
test_batch_size = 32
validation_accuracies = []

for fold, model in enumerate(model_list):
    print(f'\nFOLD: {fold+1}')
    train_score = model.evaluate(train_data[fold], batch_size=test_batch_size, verbose= 1)
    valid_score = model.evaluate(val_data[fold], batch_size=test_batch_size, verbose= 1)

    print('-' * 20)
    print("Train Loss: ", train_score[0])
    print("Train Accuracy: ", train_score[1])
    print('-' * 20)
    print("Validation Loss: ", valid_score[0])
    print("Validation Accuracy: ", valid_score[1])
    print('-' * 20)

    validation_accuracies.append(valid_score[1])
    hours = duration_list[fold]['hours']
    minutes = duration_list[fold]['minutes']
    seconds = duration_list[fold]['seconds']

    msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
    print(msg)

best_fold = np.argmax(validation_accuracies)
best_model = model_list[best_fold]
print ("Best Fold berada pada : ",best_fold)
print (best_model)
# Out:
# FOLD: 1
# 162/162 [==============================] - 15s 91ms/step - loss: 0.0123 - accuracy: 0.9967
# 41/41 [==============================] - 4s 87ms/step - loss: 0.3679 - accuracy: 0.9079
# --------------------
# Train Loss:  0.012310914695262909
# Train Accuracy:  0.9967098832130432
# --------------------
# Validation Loss:  0.36793485283851624
# Validation Accuracy:  0.9078947305679321
# --------------------
# training elapsed time was 0.0 hours, 18.0 minutes, 27.08 seconds)
#
# FOLD: 2
# 162/162 [==============================] - 15s 87ms/step - loss: 0.0016 - accuracy: 0.9998
# 41/41 [==============================] - 3s 82ms/step - loss: 0.3270 - accuracy: 0.9420
# --------------------
# Train Loss:  0.0015758108347654343
# Train Accuracy:  0.9998064637184143
# --------------------
# Validation Loss:  0.3269951343536377
# Validation Accuracy:  0.9419504404067993
# --------------------
# training elapsed time was 0.0 hours, 18.0 minutes, 54.64 seconds)
#
# FOLD: 3
# 162/162 [==============================] - 15s 91ms/step - loss: 0.2619 - accuracy: 0.9129
# 41/41 [==============================] - 4s 87ms/step - loss: 0.9519 - accuracy: 0.8135
# --------------------
# Train Loss:  0.26194053888320923
# Train Accuracy:  0.9129088521003723
# --------------------
# Validation Loss:  0.9519451856613159
# Validation Accuracy:  0.8134675025939941
# --------------------
# training elapsed time was 0.0 hours, 18.0 minutes, 10.37 seconds)
#
# FOLD: 4
# 162/162 [==============================] - 15s 91ms/step - loss: 0.0898 - accuracy: 0.9669
# 41/41 [==============================] - 4s 85ms/step - loss: 0.6417 - accuracy: 0.8831
# --------------------
# Train Loss:  0.08982271701097488
# Train Accuracy:  0.9669053554534912
# --------------------
# Validation Loss:  0.64171302318573
# Validation Accuracy:  0.8831269145011902
# --------------------
# training elapsed time was 0.0 hours, 18.0 minutes, 13.09 seconds)
#
# FOLD: 5
# 162/162 [==============================] - 14s 89ms/step - loss: 0.0021 - accuracy: 0.9994
# 41/41 [==============================] - 4s 86ms/step - loss: 0.3559 - accuracy: 0.9311
# --------------------
# Train Loss:  0.002078992547467351
# Train Accuracy:  0.9994195103645325
# --------------------
# Validation Loss:  0.35586825013160706
# Validation Accuracy:  0.9310612082481384
# --------------------
# training elapsed time was 0.0 hours, 18.0 minutes, 7.61 seconds)
# Best Fold berada pada :  1
# <keras.src.engine.sequential.Sequential object at 0x79c722dcb040>

# %%
preds = best_model.predict_generator(test_gen, verbose=1)
y_pred = np.argmax(preds, axis=1)
print(y_pred)
# Out:
# 51/51 [==============================] - 7s 109ms/step
# [0 0 1 ... 1 1 1]

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

cm = confusion_matrix(test_gen.classes, y_pred)
plot_confusion_matrix(cm= cm, classes= classes, title = 'Confusion Matrix')

    # Classification report
print(classification_report(test_gen.classes, y_pred, target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#          all       0.92      0.96      0.94       808
#          hem       0.95      0.92      0.93       807
#
#     accuracy                           0.94      1615
#    macro avg       0.94      0.94      0.94      1615
# weighted avg       0.94      0.94      0.94      1615

# %%
from sklearn import metrics


y_prob = []

for data in preds:
    y_prob.append(data[1])

fpr, tpr, thresholds = metrics.roc_curve(test_gen.classes, y_prob)
auc = metrics.auc(fpr, tpr)

plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], 'k--')  # Garis diagonal untuk klasifikasi acak
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()
